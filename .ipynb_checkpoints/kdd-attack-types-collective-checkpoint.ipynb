# %% [markdown]
# ## <font color=#6B49F5> A Simple Implementation of FedAvg with PyTorch on IID Data </font>
# Please see https://towardsdatascience.com/federated-learning-a-simple-implementation-of-fedavg-federated-averaging-with-pytorch-90187c9c9577 for more details.

# %%
import numpy as np
import pandas as pd
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
import random
import math
from torch.utils.tensorboard import SummaryWriter
from matplotlib import pyplot

from pathlib import Path
import requests
import pickle
import gzip

import torch
import math
import torch.nn.functional as F
from torch import nn
from torch import optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from imblearn.over_sampling import SMOTE
import copy
from sklearn.metrics import confusion_matrix

pd.options.display.float_format = "{:,.4f}".format
sm = SMOTE(random_state=42)

# %%
THREAT_TYPE = 'threat_type'
THREAT_HL = 'threat_hl'

learning_rate = 0.01
numEpoch = 20
batch_size = 32
momentum = 0.9
print_amount=5
number_of_slices = 5
isSmote = True

file_name = "kdd-slice-specific.txt"
file = open(file_name, "w")

data_path = "D:\\learning\\PyTorch\\NSL_KDD-master\\"

colnames = ['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land',
            'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised',
            'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells', 'num_access_files',
            'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count', 'srv_count', 'serror_rate',
            'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate',
            'srv_diff_host_rate', 'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate',
            'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate',
            'dst_host_serror_rate', 'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
            'dst_host_srv_rerror_rate', 'threat_type']

# %%
df_train = pd.read_csv(data_path + "KDDTrain+.csv", header = None)
df_train = df_train.iloc[:, :-1]

df_test = pd.read_csv(data_path + "KDDTest+.csv", header = None)
df_test = df_test.iloc[:, :-1]

df_train.columns = colnames
df_test.columns = colnames

df_train.loc[(df_train['threat_type'] == 'back'), 'threat_type'] = 1
df_train.loc[(df_train['threat_type'] == 'buffer_overflow'), 'threat_type'] = 2
df_train.loc[(df_train['threat_type'] == 'ftp_write'), 'threat_type'] = 3
df_train.loc[(df_train['threat_type'] == 'guess_passwd'), 'threat_type'] = 3
df_train.loc[(df_train['threat_type'] == 'imap'), 'threat_type'] = 3
df_train.loc[(df_train['threat_type'] == 'ipsweep'), 'threat_type'] = 4
df_train.loc[(df_train['threat_type'] == 'land'), 'threat_type'] = 1
df_train.loc[(df_train['threat_type'] == 'loadmodule'), 'threat_type'] = 2
df_train.loc[(df_train['threat_type'] == 'multihop'), 'threat_type'] = 3
df_train.loc[(df_train['threat_type'] == 'neptune'), 'threat_type'] = 1
df_train.loc[(df_train['threat_type'] == 'nmap'), 'threat_type'] = 4
df_train.loc[(df_train['threat_type'] == 'perl'), 'threat_type'] = 2
df_train.loc[(df_train['threat_type'] == 'phf'), 'threat_type'] = 3
df_train.loc[(df_train['threat_type'] == 'pod'), 'threat_type'] = 1
df_train.loc[(df_train['threat_type'] == 'portsweep'), 'threat_type'] = 4
df_train.loc[(df_train['threat_type'] == 'rootkit'), 'threat_type'] = 2
df_train.loc[(df_train['threat_type'] == 'satan'), 'threat_type'] = 4
df_train.loc[(df_train['threat_type'] == 'smurf'), 'threat_type'] = 1
df_train.loc[(df_train['threat_type'] == 'spy'), 'threat_type'] = 3
df_train.loc[(df_train['threat_type'] == 'teardrop'), 'threat_type'] = 1
df_train.loc[(df_train['threat_type'] == 'warezclient'), 'threat_type'] = 3
df_train.loc[(df_train['threat_type'] == 'warezmaster'), 'threat_type'] = 3
df_train.loc[(df_train['threat_type'] == 'normal'), 'threat_type'] = 0
df_train.loc[(df_train['threat_type'] == 'unknown'), 'threat_type'] = 6

df_test.loc[(df_test['threat_type'] == 'back'), 'threat_type'] = 1
df_test.loc[(df_test['threat_type'] == 'buffer_overflow'), 'threat_type'] = 2
df_test.loc[(df_test['threat_type'] == 'ftp_write'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'guess_passwd'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'imap'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'ipsweep'), 'threat_type'] = 4
df_test.loc[(df_test['threat_type'] == 'land'), 'threat_type'] = 1
df_test.loc[(df_test['threat_type'] == 'loadmodule'), 'threat_type'] = 2
df_test.loc[(df_test['threat_type'] == 'multihop'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'neptune'), 'threat_type'] = 1
df_test.loc[(df_test['threat_type'] == 'nmap'), 'threat_type'] = 4
df_test.loc[(df_test['threat_type'] == 'perl'), 'threat_type'] = 2
df_test.loc[(df_test['threat_type'] == 'phf'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'pod'), 'threat_type'] = 1
df_test.loc[(df_test['threat_type'] == 'portsweep'), 'threat_type'] = 4
df_test.loc[(df_test['threat_type'] == 'rootkit'), 'threat_type'] = 2
df_test.loc[(df_test['threat_type'] == 'satan'), 'threat_type'] = 4
df_test.loc[(df_test['threat_type'] == 'smurf'), 'threat_type'] = 1
df_test.loc[(df_test['threat_type'] == 'spy'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'teardrop'), 'threat_type'] = 1
df_test.loc[(df_test['threat_type'] == 'warezclient'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'warezmaster'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'normal'), 'threat_type'] = 0
df_test.loc[(df_test['threat_type'] == 'unknown'), 'threat_type'] = 6
df_test.loc[(df_test['threat_type'] == 'mscan'), 'threat_type'] = 4
df_test.loc[(df_test['threat_type'] == 'apache2'), 'threat_type'] = 1
df_test.loc[(df_test['threat_type'] == 'snmpgetattack'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'processtable'), 'threat_type'] = 1
df_test.loc[(df_test['threat_type'] == 'httptunnel'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'ps'), 'threat_type'] = 2
df_test.loc[(df_test['threat_type'] == 'snmpguess'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'mailbomb'), 'threat_type'] = 1
df_test.loc[(df_test['threat_type'] == 'named'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'sendmail'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'xterm'), 'threat_type'] = 2
df_test.loc[(df_test['threat_type'] == 'xlock'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'xsnoop'), 'threat_type'] = 3
df_test.loc[(df_test['threat_type'] == 'sqlattack'), 'threat_type'] = 2
df_test.loc[(df_test['threat_type'] == 'udpstorm'), 'threat_type'] = 1
df_test.loc[(df_test['threat_type'] == 'saint'), 'threat_type'] = 4
df_test.loc[(df_test['threat_type'] == 'worm'), 'threat_type'] = 1

df_full = pd.concat([df_train, df_test])

print('Attack types in full set: \n', df_full[THREAT_TYPE].value_counts())
# Out:
# Attack types in full set:
#  0    77053
# 1    53387
# 4    14077
# 3     3880
# 2      119
# Name: threat_type, dtype: int64

# %%
print('Before normalization shape of data set : ', df_full.shape)
threat_type_df = df_full['threat_type'].copy()
# Considering numerical columns
# 34 numerical columns are considered for training
numerical_colmanes = ['duration', 'src_bytes', 'dst_bytes', 'wrong_fragment', 'urgent', 'hot',
                      'num_failed_logins', 'num_compromised', 'root_shell', 'su_attempted', 'num_root',
                      'num_file_creations', 'num_shells', 'num_access_files', 'num_outbound_cmds', 'count',
                      'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate',
                      'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
                      'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate',
                      'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
                      'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate']

numerical_df_full = df_full[numerical_colmanes].copy()
print(numerical_df_full.shape)
#
# # Lets remove the numerical columns with constant value
numerical_df_full = numerical_df_full.loc[:, (numerical_df_full != numerical_df_full.iloc[0]).any()]
#
# # lets scale the values for each column from [0,1]
# # N.B. we dont have any negative values]
final_df_full = numerical_df_full / numerical_df_full.max()
print(final_df_full.shape)

df_normalized = pd.concat([final_df_full, threat_type_df], axis=1)
print('After normalization shape of data set: ', df_normalized.shape)
print(df_normalized[THREAT_TYPE].value_counts())
# Out:
# Before normalization shape of data set :  (148516, 42)
# (148516, 34)
# (148516, 33)
# After normalization shape of data set:  (148516, 34)
# 0    77053
# 1    53387
# 4    14077
# 3     3880
# 2      119
# Name: threat_type, dtype: int64

# %%
df_normal = df_normalized[df_normalized['threat_type'] == 0]
df_dos = df_normalized[df_normalized['threat_type'] == 1]
df_u2r = df_normalized[df_normalized['threat_type'] == 2]
df_r2u = df_normalized[df_normalized['threat_type'] == 3]
df_probe = df_normalized[df_normalized['threat_type'] == 4]

print(df_normal.shape, df_dos.shape, df_u2r.shape, df_r2u.shape, df_probe.shape)
# Out:
# (77053, 34) (53387, 34) (119, 34) (3880, 34) (14077, 34)

# %%
def divide_train_test(df, propotion=0.1):
    
    df_train = []
    df_test = []
    for key,val in df[THREAT_TYPE].value_counts().iteritems():
        df_part = df[df['threat_type'] == key]
        df_test.append(df_part[0: int(df_part.shape[0]*propotion)])
        df_train.append(df_part[int(df_part.shape[0]*propotion):df_part.shape[0]])
        
    return df_train,df_test

# %%
def get_data_for_slices(df_train, number_of_slices, isSmote=False, x_name="x_train", y_name="y_train"):
    df_normal_s1 = df_normal[int(df_normal.shape[0]*0/number_of_slices):int(df_normal.shape[0]*(1)/number_of_slices)]
    df_normal_s2 = df_normal[int(df_normal.shape[0]*1/number_of_slices):int(df_normal.shape[0]*(2)/number_of_slices)]
    df_normal_s3 = df_normal[int(df_normal.shape[0]*2/number_of_slices):int(df_normal.shape[0]*(3)/number_of_slices)]
    df_normal_s4 = df_normal[int(df_normal.shape[0]*3/number_of_slices):int(df_normal.shape[0]*(4)/number_of_slices)]
    df_normal_s5 = df_normal[int(df_normal.shape[0]*4/number_of_slices):int(df_normal.shape[0]*(5)/number_of_slices)]

    df_s1 = pd.concat([df_normal_s1,df_dos])
    df_s2 = pd.concat([df_normal_s2,df_u2r])
    df_s3 = pd.concat([df_normal_s3,df_r2u])
    df_s4 = pd.concat([df_normal_s4,df_probe])
    df_s5 = df_normal_s5

    x_data_dict= dict()
    y_data_dict= dict()

    y_s1 = (df_s1.pop('threat_type').values).astype('int')
    unique, counts = np.unique(y_s1, return_counts=True)
    print('slice 1: ')
    print(dict(zip(unique, counts)))
    y_info1 = torch.tensor(y_s1).type(torch.LongTensor)
    x_info1 = torch.tensor(df_s1.values).float()

    y_s2 = (df_s2.pop('threat_type').values).astype('int')
    unique, counts = np.unique(y_s2, return_counts=True)
    print('slice 2: ')
    print(dict(zip(unique, counts)))
    y_info2 = torch.tensor(y_s2).type(torch.LongTensor)
    x_info2 = torch.tensor(df_s2.values).float()

    y_s3 = (df_s3.pop('threat_type').values).astype('int')
    unique, counts = np.unique(y_s3, return_counts=True)
    print('slice 3: ')
    print( dict(zip(unique, counts)))
    y_info3 = torch.tensor(y_s3).type(torch.LongTensor)
    x_info3 = torch.tensor(df_s3.values).float()

    y_s4 = (df_s4.pop('threat_type').values).astype('int')
    unique, counts = np.unique(y_s4, return_counts=True)
    print('slice 4: ')
    print(dict(zip(unique, counts)))
    y_info4 = torch.tensor(y_s4).type(torch.LongTensor)
    x_info4 = torch.tensor(df_s4.values).float()

    y_s5 = (df_s5.pop('threat_type').values).astype('int')
    unique, counts = np.unique(y_s5, return_counts=True)
    print('slice 5: ')
    print(dict(zip(unique, counts)))
    y_info5 = torch.tensor(y_s5).type(torch.LongTensor)
    x_info5 = torch.tensor(df_s5.values).float()


    x_data_dict.update({"x_train0" : x_info1})
    y_data_dict.update({"y_train0" : y_info1})

    x_data_dict.update({"x_train1" : x_info2})
    y_data_dict.update({"y_train1" : y_info2})

    x_data_dict.update({"x_train2" : x_info3})
    y_data_dict.update({"y_train2" : y_info3})

    x_data_dict.update({"x_train3" : x_info4})
    y_data_dict.update({"y_train3" : y_info4})

    x_data_dict.update({"x_train4" : x_info5})
    y_data_dict.update({"y_train4" : y_info5})
    
    return x_data_dict, y_data_dict

# %%
df_train, df_test = divide_train_test(df_normalized,propotion=0.1)
# print('Value counts in train set : ')
# df_train[THREAT_TYPE].value_counts()
# print('Value counts in test set : ')
# print(df_test[THREAT_TYPE].value_counts())

x_train_dict, y_train_dict = get_data_for_slices(df_train, number_of_slices, isSmote)

for y_train_s in y_train_dict:
    print(y_train_s)
df_test = pd.concat(df_test)
y_test = df_test.pop(THREAT_TYPE).values
x_test = df_test.values

print('Test set size is : x => ' + str(x_test.shape) + ' y => ' + str(y_test.shape))
x_test = torch.tensor(x_test).float()
y_test = torch.tensor(y_test.astype('int')).type(torch.LongTensor)

inputs = x_test.shape[1]
outputs = 5
# Out:
# slice 1:
# {0: 15410, 1: 53387}
# slice 2:
# {0: 15411, 2: 119}
# slice 3:
# {0: 15410, 3: 3880}
# slice 4:
# {0: 15411, 4: 14077}
# slice 5:
# {0: 15411}
# y_train0
# y_train1
# y_train2
# y_train3
# y_train4
# Test set size is : x => (14849, 33) y => (14849,)

# %% [markdown]
# --------------------------
# ### <span style="background-color:#F087F9"> Classification Model </span>

# %%
class Net2nn(nn.Module):
    def __init__(self, inputs, outputs):
        super(Net2nn, self).__init__()
        self.fc1=nn.Linear(inputs,200)
        self.fc2=nn.Linear(200,200)
        self.fc3=nn.Linear(200,outputs)
        
    def forward(self,x):
        x=F.relu(self.fc1(x))
        x=F.relu(self.fc2(x))
        x=self.fc3(x)
        return x

# %%
class WrappedDataLoader:
    def __init__(self, dl, func):
        self.dl = dl
        self.func = func

    def __len__(self):
        return len(self.dl)

    def __iter__(self):
        batches = iter(self.dl)
        for b in batches:
            yield (self.func(*b))

# %%
def train(model, train_loader, criterion, optimizer):
    model.train()
    train_loss = 0.0
    correct = 0

    for data, target in train_loader:
        output = model(data)
        loss = criterion(output, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        prediction = output.argmax(dim=1, keepdim=True)
        correct += prediction.eq(target.view_as(prediction)).sum().item()
        

    return train_loss / len(train_loader), correct/len(train_loader.dataset)

# %%
def validation(model, test_loader, criterion):
    model.eval()
    test_loss = 0.0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            output = model(data)
            
            test_loss += criterion(output, target).item()
            prediction = output.argmax(dim=1, keepdim=True)
            correct += prediction.eq(target.view_as(prediction)).sum().item()

    test_loss /= len(test_loader)
    correct /= len(test_loader.dataset)

    return (test_loss, correct)

# %%
def confusion_mat(model, test_loader, desc = 'none'):
    
    print(desc)
    y_pred = []
    y_true = []

    # iterate over test data
    for inputs, labels in test_loader:
        output = model(inputs)  # Feed Network

        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output)  # Save Prediction

        labels = labels.data.cpu().numpy()
        y_true.extend(labels)  # Save Truth

    cf_matrix = confusion_matrix(y_true, y_pred)
#     df_cm = pd.DataFrame(cf_matrix, index=[i for i in Counter(y_test)],
#                          columns=[i for i in Counter(y_test)])
#     plt.figure(1)
#     plt.ylabel('True label')
#     plt.xlabel('Predicted label')
#     plt.figure(figsize=(12, 7))

#     sn.heatmap(df_cm, annot=True).set(xlabel='Predicted label', ylabel='True label')
#     plt.savefig('D:\\learning\\PyTorch\\experiment\\cf\\cf_fl_'+str(self.number_of_slices)+'.png')
    print('confusion matrix for normal scenario for slices : ' + str(number_of_slices))
    print(cf_matrix)
    file.write('\ncf matrix for slice :' + str(number_of_slices))
    file.write('\n'+str(cf_matrix))

# %% [markdown]
# ---------------------------------
# ### <span style="background-color:#F087F9"> Functions for Federated Averaging </span>

# %%
def create_model_optimizer_criterion_dict(number_of_slices):
    model_dict = dict()
    optimizer_dict= dict()
    criterion_dict = dict()
    
    for i in range(number_of_slices):
        model_name="model"+str(i)
        model_info=Net2nn(inputs, outputs)
        model_dict.update({model_name : model_info })
        
        optimizer_name="optimizer"+str(i)
        optimizer_info = torch.optim.SGD(model_info.parameters(), lr=learning_rate, momentum=momentum)
        optimizer_dict.update({optimizer_name : optimizer_info })
        
        criterion_name = "criterion"+str(i)
        criterion_info = nn.CrossEntropyLoss()
        criterion_dict.update({criterion_name : criterion_info})
        
    return model_dict, optimizer_dict, criterion_dict

# %%
def get_averaged_weights(model_dict, number_of_slices):
   
    fc1_mean_weight = torch.zeros(size=model_dict[name_of_models[0]].fc1.weight.shape)
    fc1_mean_bias = torch.zeros(size=model_dict[name_of_models[0]].fc1.bias.shape)
    
    fc2_mean_weight = torch.zeros(size=model_dict[name_of_models[0]].fc2.weight.shape)
    fc2_mean_bias = torch.zeros(size=model_dict[name_of_models[0]].fc2.bias.shape)
    
    fc3_mean_weight = torch.zeros(size=model_dict[name_of_models[0]].fc3.weight.shape)
    fc3_mean_bias = torch.zeros(size=model_dict[name_of_models[0]].fc3.bias.shape)
    
    with torch.no_grad():
    
    
        for i in range(number_of_slices):
            fc1_mean_weight += model_dict[name_of_models[i]].fc1.weight.data.clone()
            fc1_mean_bias += model_dict[name_of_models[i]].fc1.bias.data.clone()
        
            fc2_mean_weight += model_dict[name_of_models[i]].fc2.weight.data.clone()
            fc2_mean_bias += model_dict[name_of_models[i]].fc2.bias.data.clone()
        
            fc3_mean_weight += model_dict[name_of_models[i]].fc3.weight.data.clone()
            fc3_mean_bias += model_dict[name_of_models[i]].fc3.bias.data.clone()

        
        fc1_mean_weight =fc1_mean_weight/number_of_slices
        fc1_mean_bias = fc1_mean_bias/ number_of_slices
    
        fc2_mean_weight =fc2_mean_weight/number_of_slices
        fc2_mean_bias = fc2_mean_bias/ number_of_slices
    
        fc3_mean_weight =fc3_mean_weight/number_of_slices
        fc3_mean_bias = fc3_mean_bias/ number_of_slices
    
    return fc1_mean_weight, fc1_mean_bias, fc2_mean_weight, fc2_mean_bias, fc3_mean_weight, fc3_mean_bias

# %%
def set_averaged_weights_as_main_model_weights_and_update_main_model(main_model,model_dict, number_of_slices):
    fc1_mean_weight, fc1_mean_bias, fc2_mean_weight, fc2_mean_bias, fc3_mean_weight, fc3_mean_bias = get_averaged_weights(model_dict, number_of_slices=number_of_slices)
    with torch.no_grad():
        main_model.fc1.weight.data = fc1_mean_weight.data.clone()
        main_model.fc2.weight.data = fc2_mean_weight.data.clone()
        main_model.fc3.weight.data = fc3_mean_weight.data.clone()

        main_model.fc1.bias.data = fc1_mean_bias.data.clone()
        main_model.fc2.bias.data = fc2_mean_bias.data.clone()
        main_model.fc3.bias.data = fc3_mean_bias.data.clone() 
    return main_model

# %%
def compare_local_and_merged_model_performance(number_of_slices):
    accuracy_table=pd.DataFrame(data=np.zeros((number_of_slices,3)), columns=["sample", "local_ind_model", "merged_main_model"])
    for i in range (number_of_slices):
    
        test_ds = TensorDataset(x_test, y_test)
        test_dl = DataLoader(test_ds, batch_size=batch_size * 2)
    
        model=model_dict[name_of_models[i]]
        criterion=criterion_dict[name_of_criterions[i]]
        optimizer=optimizer_dict[name_of_optimizers[i]]
    
        individual_loss, individual_accuracy = validation(model, test_dl, criterion)
        main_loss, main_accuracy =validation(main_model, test_dl, main_criterion )
    
        accuracy_table.loc[i, "sample"]="sample "+str(i)
        accuracy_table.loc[i, "local_ind_model"] = individual_accuracy
        accuracy_table.loc[i, "merged_main_model"] = main_accuracy

    return accuracy_table

# %%
def send_main_model_to_nodes_and_update_model_dict(main_model, model_dict, number_of_slices):
    with torch.no_grad():
        for i in range(number_of_slices):
            print('Updating model :' + name_of_models[i] )
            model_dict[name_of_models[i]].fc1.weight.data =main_model.fc1.weight.data.clone()
            model_dict[name_of_models[i]].fc2.weight.data =main_model.fc2.weight.data.clone()
            model_dict[name_of_models[i]].fc3.weight.data =main_model.fc3.weight.data.clone() 
            
            model_dict[name_of_models[i]].fc1.bias.data =main_model.fc1.bias.data.clone()
            model_dict[name_of_models[i]].fc2.bias.data =main_model.fc2.bias.data.clone()
            model_dict[name_of_models[i]].fc3.bias.data =main_model.fc3.bias.data.clone() 
    
    return model_dict

# %%
def start_train_end_node_process(number_of_slices):
    for i in range (number_of_slices): 

        print('Federated learning for slice '+ str(i+1))
        train_ds = TensorDataset(x_train_dict[name_of_x_train_sets[i]], y_train_dict[name_of_y_train_sets[i]])
        train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)

#         valid_ds = TensorDataset(x_valid_dict[name_of_x_valid_sets[i]], y_valid_dict[name_of_y_valid_sets[i]])
#         valid_dl = DataLoader(valid_ds, batch_size=batch_size * 2)
        
        test_ds = TensorDataset(x_test_dict[name_of_x_test_sets[i]], y_test_dict[name_of_y_test_sets[i]])
        test_dl = DataLoader(test_ds, batch_size= batch_size * 2)
    
        model=model_dict[name_of_models[i]]
        criterion=criterion_dict[name_of_criterions[i]]
        optimizer=optimizer_dict[name_of_optimizers[i]]
    
        print("Subset" ,i)
        for epoch in range(numEpoch):        
            train_loss, train_accuracy = train(model, train_dl, criterion, optimizer)
#             valid_loss, valid_accuracy = validation(model, valid_dl, criterion)
            test_loss, test_accuracy = validation(model, test_dl, criterion)
    
            print("epoch: {:3.0f}".format(epoch+1) + " | train accuracy: {:7.5f}".format(train_accuracy) + " | test accuracy: {:7.5f}".format(test_accuracy))

# %%
def start_train_end_node_process_without_print(number_of_slices):
    for i in range (number_of_slices): 

        train_ds = TensorDataset(x_train_dict[name_of_x_train_sets[i]], y_train_dict[name_of_y_train_sets[i]])
        train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)

        test_ds = TensorDataset(x_test, y_test)
        test_dl = DataLoader(test_ds, batch_size= batch_size * 2)
    
        model=model_dict[name_of_models[i]]
        criterion=criterion_dict[name_of_criterions[i]]
        optimizer=optimizer_dict[name_of_optimizers[i]]
    
        for epoch in range(numEpoch):        
            train_loss, train_accuracy = train(model, train_dl, criterion, optimizer)
            test_loss, test_accuracy = validation(model, test_dl, criterion)
            
        confusion_mat(model, test_dl, desc = 'Confusion matrix for ' + name_of_models[i])

# %%
def start_train_end_node_process_print_some(number_of_slices, print_amount):
    for i in range (number_of_slices): 
        
        print('Federated learning for slice '+ str(i+1))
        train_ds = TensorDataset(x_train_dict[name_of_x_train_sets[i]], 
                                 y_train_dict[name_of_y_train_sets[i]])
        train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)

        test_ds = TensorDataset(x_test, y_test)
        test_dl = DataLoader(test_ds, batch_size= batch_size * 2)
    
        model=model_dict[name_of_models[i]]
        criterion=criterion_dict[name_of_criterions[i]]
        optimizer=optimizer_dict[name_of_optimizers[i]]
    
        if i<print_amount:
            print("Subset" ,i)
            
        for epoch in range(numEpoch):
        
            train_loss, train_accuracy = train(model, train_dl, criterion, optimizer)
            test_loss, test_accuracy = validation(model, test_dl, criterion)
            
            if i<print_amount:        
                print("epoch: {:3.0f}".format(epoch+1) + " | train accuracy: {:7.5f}".format(train_accuracy) + " | test accuracy: {:7.5f}".format(test_accuracy)) 
                
        confusion_mat(model, test_dl, desc = 'Confusion matrix for ' + name_of_models[i])

# %%
# x_train, y_train, x_valid, y_valid,x_test, y_test = map(torch.tensor, (x_train, y_train, x_valid, y_valid, x_test, y_test))

# %% [markdown]
# ----------------
#
# ### <span style="background-color:#F087F9"> Let's examine what would the performance of the centralized model be if the data were not distributed to nodes at all? </span>
#
# The model used in this example is very simple, different things can be done to improve model performance, such as using more complex models, increasing epoch or hyperparameter tuning. However, the purpose here is to compare the performance of the main model that is formed by combining the parameters of the local models trained on their own data with a centralized model that trained on all training data. In this way, we can gain insight into the capacity of federated learning.

# %%
# initial_model = Net2nn()
# initial_optimizer = torch.optim.SGD(initial_model.parameters(), lr=0.01, momentum=0.9)
# initial_criterion = nn.CrossEntropyLoss()

centralized_model = Net2nn(inputs, outputs)
centralized_optimizer = torch.optim.SGD(centralized_model.parameters(), lr=0.01, momentum=0.9)
centralized_criterion = nn.CrossEntropyLoss()

# %%
print("------ Centralized Model ------")

train_acc = []
test_acc = []
train_loss = []
test_loss = []

test_ds = TensorDataset(x_test, y_test)
test_dl = DataLoader(test_ds, batch_size=batch_size * 2)

centralized_model = Net2nn(inputs,outputs)
centralized_optimizer = torch.optim.SGD(centralized_model.parameters(), lr=0.01, momentum=0.9)
centralized_criterion = nn.CrossEntropyLoss()
#     centralized_model = copy.deepcopy(initial_model)
#     centralized_optimizer = copy.deepcopy(initial_optimizer)
#     centralized_criterion = copy.deepcopy(initial_criterion)
x_name = 'x_train' + str(4)
y_name = 'y_train' + str(4)
train_ds = TensorDataset(x_train_dict[x_name], y_train_dict[y_name])
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)

for epoch in range(numEpoch):
    central_train_loss, central_train_accuracy = train(centralized_model, train_dl, centralized_criterion, centralized_optimizer)
    central_test_loss, central_test_accuracy = validation(centralized_model, test_dl, centralized_criterion)

    train_acc.append(central_train_accuracy)
    train_loss.append(central_train_loss)
    test_acc.append(central_test_accuracy)
    test_loss.append(central_test_loss)

#         print("epoch: {:3.0f}".format(epoch+1) + " | train accuracy: {:7.4f}".format(central_train_accuracy) + " | test accuracy: {:7.4f}".format(central_test_accuracy))
print(" | train accuracy: {:7.4f}".format(central_train_accuracy) + " | test accuracy: {:7.4f}".format(central_test_accuracy))
confusion_mat(centralized_model, test_dl)

print(centralized_model.fc2.weight[0:1,0:5])  
print("------ Training finished ------")
print('Mean train accuracy: ' + str(sum(train_acc)/len(train_acc)))
print('Mean test accuracy: ' + str(sum(test_acc)/len(test_acc)))
# Out:
# ------ Centralized Model ------
#  | train accuracy:  1.0000 | test accuracy:  0.5189
# none
# confusion matrix for normal scenario for slices : 5
# [[7705    0    0    0    0]
#  [5338    0    0    0    0]
#  [  11    0    0    0    0]
#  [ 388    0    0    0    0]
#  [1407    0    0    0    0]]
# tensor([[-0.0037, -0.0536,  0.0416, -0.0259, -0.0454]],
#        grad_fn=<SliceBackward>)
# ------ Training finished ------
# Mean train accuracy: 0.9997144896502498
# Mean test accuracy: 0.5188901609535995

# %%
file.write('\nCentralized Mean train accuracy: ' + str(sum(train_acc)/len(train_acc)))
file.write('\nCentralized Mean test accuracy: ' + str(sum(test_acc)/len(test_acc)))
# Out:
# 51

# %% [markdown]
# ----------------
# -----------------
# **Data is distributed to nodes**
#
# <!-- ### <span style="background-color:#F087F9"> Datanın nodelara dağıtılması </span>    -->

# %%
print(x_train_dict["x_train1"].shape, y_train_dict["y_train1"].shape)
print(x_test.shape, y_test.shape)
# Out:
# torch.Size([15530, 33]) torch.Size([15530])
# torch.Size([14849, 33]) torch.Size([14849])

# %% [markdown]
# **Main model is created**

# %%
main_model = Net2nn(inputs,outputs)
main_optimizer = torch.optim.SGD(main_model.parameters(), lr=learning_rate, momentum=0.9)
main_criterion = nn.CrossEntropyLoss()

# %% [markdown]
# **Models,optimizers and loss functions in nodes are defined**

# %%
model_dict, optimizer_dict, criterion_dict = create_model_optimizer_criterion_dict(number_of_slices)

# %% [markdown]
# **Keys of dicts are being made iterable**

# %%
name_of_x_train_sets=list(x_train_dict.keys())
name_of_y_train_sets=list(y_train_dict.keys())

name_of_models=list(model_dict.keys())
name_of_optimizers=list(optimizer_dict.keys())
name_of_criterions=list(criterion_dict.keys())

print(name_of_x_train_sets)
print(name_of_y_train_sets)
print("\n ------------")
print(name_of_models)
print(name_of_optimizers)
print(name_of_criterions)
# Out:
# ['x_train0', 'x_train1', 'x_train2', 'x_train3', 'x_train4']
# ['y_train0', 'y_train1', 'y_train2', 'y_train3', 'y_train4']
#
#  ------------
# ['model0', 'model1', 'model2', 'model3', 'model4']
# ['optimizer0', 'optimizer1', 'optimizer2', 'optimizer3', 'optimizer4']
# ['criterion0', 'criterion1', 'criterion2', 'criterion3', 'criterion4']

# %%
print(main_model.fc2.weight[0:1,0:5])
print(model_dict["model1"].fc2.weight[0:1,0:5])
# Out:
# tensor([[-0.0462, -0.0455,  0.0013,  0.0076, -0.0170]],
#        grad_fn=<SliceBackward>)
# tensor([[ 0.0278,  0.0307, -0.0385,  0.0490, -0.0622]],
#        grad_fn=<SliceBackward>)

# %% [markdown]
# **Parameters of main model are sent to nodes**
# Since the parameters of the main model and parameters of all local models in the nodes are randomly initialized, all these parameters will be different from each other. For this reason, the main model sends its parameters to the nodes before the training of local models in the nodes begins. You can check the weights below.

# %%
model_dict=send_main_model_to_nodes_and_update_model_dict(main_model, model_dict, number_of_slices)
# Out:
# Updating model :model0
# Updating model :model1
# Updating model :model2
# Updating model :model3
# Updating model :model4

# %%
print(main_model.fc2.weight[0:1,0:5])
print(model_dict["model1"].fc2.weight[0:1,0:5])
print(model_dict["model0"].fc2.weight[0,0:5])
print(model_dict["model1"].fc2.weight[0,0:5])
print(model_dict["model2"].fc2.weight[0,0:5])
print(model_dict["model3"].fc2.weight[0,0:5])
print(model_dict["model4"].fc2.weight[0,0:5])
# Out:
# tensor([[-0.0462, -0.0455,  0.0013,  0.0076, -0.0170]],
#        grad_fn=<SliceBackward>)
# tensor([[-0.0462, -0.0455,  0.0013,  0.0076, -0.0170]],
#        grad_fn=<SliceBackward>)
# tensor([-0.0462, -0.0455,  0.0013,  0.0076, -0.0170], grad_fn=<SliceBackward>)
# tensor([-0.0462, -0.0455,  0.0013,  0.0076, -0.0170], grad_fn=<SliceBackward>)
# tensor([-0.0462, -0.0455,  0.0013,  0.0076, -0.0170], grad_fn=<SliceBackward>)
# tensor([-0.0462, -0.0455,  0.0013,  0.0076, -0.0170], grad_fn=<SliceBackward>)
# tensor([-0.0462, -0.0455,  0.0013,  0.0076, -0.0170], grad_fn=<SliceBackward>)

# %% [markdown]
# **Models in the nodes are trained**

# %%
# start_train_end_node_process()
start_train_end_node_process_print_some(number_of_slices, print_amount)
# Out:
# Federated learning for slice 1
# Subset 0
# epoch:   1 | train accuracy: 0.95705 | test accuracy: 0.85164
# epoch:   2 | train accuracy: 0.97834 | test accuracy: 0.86262
# epoch:   3 | train accuracy: 0.98387 | test accuracy: 0.86935
# epoch:   4 | train accuracy: 0.98498 | test accuracy: 0.86807
# epoch:   5 | train accuracy: 0.98735 | test accuracy: 0.83198
# epoch:   6 | train accuracy: 0.98769 | test accuracy: 0.86679
# epoch:   7 | train accuracy: 0.98802 | test accuracy: 0.86444
# epoch:   8 | train accuracy: 0.99009 | test accuracy: 0.87023
# epoch:   9 | train accuracy: 0.99116 | test accuracy: 0.86800
# epoch:  10 | train accuracy: 0.99064 | test accuracy: 0.86612
# epoch:  11 | train accuracy: 0.99134 | test accuracy: 0.85912
# epoch:  12 | train accuracy: 0.99124 | test accuracy: 0.86134
# epoch:  13 | train accuracy: 0.99192 | test accuracy: 0.83878
# epoch:  14 | train accuracy: 0.99230 | test accuracy: 0.87299
# epoch:  15 | train accuracy: 0.99217 | test accuracy: 0.87016
# epoch:  16 | train accuracy: 0.99238 | test accuracy: 0.86861
# epoch:  17 | train accuracy: 0.99260 | test accuracy: 0.86073
# epoch:  18 | train accuracy: 0.99233 | test accuracy: 0.87184
# epoch:  19 | train accuracy: 0.99279 | test accuracy: 0.86854
# epoch:  20 | train accuracy: 0.99318 | test accuracy: 0.86814
# Confusion matrix for model0
# confusion matrix for normal scenario for slices : 5
# [[7567  138    0    0    0]
#  [  14 5324    0    0    0]
#  [   9    2    0    0    0]
#  [ 347   41    0    0    0]
#  [ 786  621    0    0    0]]
# Federated learning for slice 2
# Subset 1
# epoch:   1 | train accuracy: 0.98397 | test accuracy: 0.51889
# epoch:   2 | train accuracy: 0.99234 | test accuracy: 0.51889
# epoch:   3 | train accuracy: 0.99234 | test accuracy: 0.51889
# epoch:   4 | train accuracy: 0.99234 | test accuracy: 0.51889
# epoch:   5 | train accuracy: 0.99337 | test accuracy: 0.51909
# epoch:   6 | train accuracy: 0.99472 | test accuracy: 0.51902
# epoch:   7 | train accuracy: 0.99504 | test accuracy: 0.51896
# epoch:   8 | train accuracy: 0.99511 | test accuracy: 0.51882
# epoch:   9 | train accuracy: 0.99530 | test accuracy: 0.51896
# epoch:  10 | train accuracy: 0.99511 | test accuracy: 0.51902
# epoch:  11 | train accuracy: 0.99536 | test accuracy: 0.51902
# epoch:  12 | train accuracy: 0.99536 | test accuracy: 0.51896
# epoch:  13 | train accuracy: 0.99543 | test accuracy: 0.51916
# epoch:  14 | train accuracy: 0.99543 | test accuracy: 0.51896
# epoch:  15 | train accuracy: 0.99530 | test accuracy: 0.51902
# epoch:  16 | train accuracy: 0.99543 | test accuracy: 0.51916
# epoch:  17 | train accuracy: 0.99543 | test accuracy: 0.51916
# epoch:  18 | train accuracy: 0.99543 | test accuracy: 0.51909
# epoch:  19 | train accuracy: 0.99549 | test accuracy: 0.51909
# epoch:  20 | train accuracy: 0.99543 | test accuracy: 0.51916
# Confusion matrix for model1
# confusion matrix for normal scenario for slices : 5
# [[7703    0    2    0    0]
#  [5338    0    0    0    0]
#  [   5    0    6    0    0]
#  [ 387    0    1    0    0]
#  [1407    0    0    0    0]]
# Federated learning for slice 3
# Subset 2
# epoch:   1 | train accuracy: 0.82556 | test accuracy: 0.51943
# epoch:   2 | train accuracy: 0.88331 | test accuracy: 0.51943
# epoch:   3 | train accuracy: 0.89285 | test accuracy: 0.47646
# epoch:   4 | train accuracy: 0.89772 | test accuracy: 0.52852
# epoch:   5 | train accuracy: 0.90078 | test accuracy: 0.53041
# epoch:   6 | train accuracy: 0.90005 | test accuracy: 0.52280
# epoch:   7 | train accuracy: 0.90358 | test accuracy: 0.53243
# epoch:   8 | train accuracy: 0.90555 | test accuracy: 0.52131
# epoch:   9 | train accuracy: 0.90617 | test accuracy: 0.52556
# epoch:  10 | train accuracy: 0.90804 | test accuracy: 0.52428
# epoch:  11 | train accuracy: 0.91156 | test accuracy: 0.52852
# epoch:  12 | train accuracy: 0.91146 | test accuracy: 0.51579
# epoch:  13 | train accuracy: 0.91643 | test accuracy: 0.52536
# epoch:  14 | train accuracy: 0.91700 | test accuracy: 0.50939
# epoch:  15 | train accuracy: 0.91685 | test accuracy: 0.52333
# epoch:  16 | train accuracy: 0.91436 | test accuracy: 0.51855
# epoch:  17 | train accuracy: 0.91965 | test accuracy: 0.52158
# epoch:  18 | train accuracy: 0.91597 | test accuracy: 0.53290
# epoch:  19 | train accuracy: 0.91685 | test accuracy: 0.53182
# epoch:  20 | train accuracy: 0.92053 | test accuracy: 0.52960
# Confusion matrix for model2
# confusion matrix for normal scenario for slices : 5
# [[7509    0    0  196    0]
#  [5316    0    0   22    0]
#  [   4    0    0    7    0]
#  [  33    0    0  355    0]
#  [1133    0    0  274    0]]
# Federated learning for slice 4
# Subset 3
# epoch:   1 | train accuracy: 0.93709 | test accuracy: 0.59627
# epoch:   2 | train accuracy: 0.96653 | test accuracy: 0.59499
# epoch:   3 | train accuracy: 0.97056 | test accuracy: 0.60199
# epoch:   4 | train accuracy: 0.97477 | test accuracy: 0.59849
# epoch:   5 | train accuracy: 0.97589 | test accuracy: 0.60199
# epoch:   6 | train accuracy: 0.97769 | test accuracy: 0.60401
# epoch:   7 | train accuracy: 0.97897 | test accuracy: 0.59883
# epoch:   8 | train accuracy: 0.97969 | test accuracy: 0.60469
# epoch:   9 | train accuracy: 0.98074 | test accuracy: 0.59943
# epoch:  10 | train accuracy: 0.98209 | test accuracy: 0.60529
# epoch:  11 | train accuracy: 0.98155 | test accuracy: 0.60536
# epoch:  12 | train accuracy: 0.98274 | test accuracy: 0.60543
# epoch:  13 | train accuracy: 0.98291 | test accuracy: 0.60422
# epoch:  14 | train accuracy: 0.98369 | test accuracy: 0.60354
# epoch:  15 | train accuracy: 0.98359 | test accuracy: 0.59560
# epoch:  16 | train accuracy: 0.98379 | test accuracy: 0.60529
# epoch:  17 | train accuracy: 0.98311 | test accuracy: 0.60516
# epoch:  18 | train accuracy: 0.98413 | test accuracy: 0.60576
# epoch:  19 | train accuracy: 0.98440 | test accuracy: 0.60280
# epoch:  20 | train accuracy: 0.98606 | test accuracy: 0.60556
# Confusion matrix for model3
# confusion matrix for normal scenario for slices : 5
# [[7645    0    0    0   60]
#  [ 427    0    0    0 4911]
#  [  11    0    0    0    0]
#  [ 369    0    0    0   19]
#  [  60    0    0    0 1347]]
# Federated learning for slice 5
# Subset 4
# epoch:   1 | train accuracy: 0.99169 | test accuracy: 0.51889
# epoch:   2 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   3 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   4 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   5 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   6 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   7 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   8 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   9 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  10 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  11 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  12 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  13 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  14 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  15 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  16 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  17 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  18 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  19 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  20 | train accuracy: 1.00000 | test accuracy: 0.51889
# Confusion matrix for model4
# confusion matrix for normal scenario for slices : 5
# [[7705    0    0    0    0]
#  [5338    0    0    0    0]
#  [  11    0    0    0    0]
#  [ 388    0    0    0    0]
#  [1407    0    0    0    0]]

# %%
## As you can see, wieghts of local models are updated after training process
print(main_model.fc2.weight[0,0:5])
print(model_dict["model0"].fc2.weight[0,0:5])
print(model_dict["model1"].fc2.weight[0,0:5])
print(model_dict["model2"].fc2.weight[0,0:5])
print(model_dict["model3"].fc2.weight[0,0:5])
print(model_dict["model4"].fc2.weight[0,0:5])
# Out:
# tensor([-0.0462, -0.0455,  0.0013,  0.0076, -0.0170], grad_fn=<SliceBackward>)
# tensor([-0.0467, -0.0525,  0.0013,  0.0019, -0.0297], grad_fn=<SliceBackward>)
# tensor([-0.0469, -0.0481,  0.0013,  0.0078, -0.0208], grad_fn=<SliceBackward>)
# tensor([-0.0491, -0.0428,  0.0016,  0.0076, -0.0181], grad_fn=<SliceBackward>)
# tensor([-0.0428, -0.0293,  0.0026,  0.0092, -0.0166], grad_fn=<SliceBackward>)
# tensor([-0.0468, -0.0482,  0.0013,  0.0075, -0.0210], grad_fn=<SliceBackward>)

# %% [markdown]
# ### Let's compare the performance of federated main model, individual local models and centralized model
#
# **Federated main model vs individual local models before 1st iteration (on distributed test set)**
# Since main model is randomly initialized and no action taken on it yet, its performance is very poor. Please before_acc_table

# %%
before_acc_table=compare_local_and_merged_model_performance(number_of_slices=number_of_slices)
before_test_loss, before_test_accuracy = validation(main_model, test_dl, main_criterion)
file.write('\nbefore training main model')
confusion_mat(main_model, test_dl)

main_model= set_averaged_weights_as_main_model_weights_and_update_main_model(main_model,model_dict, number_of_slices) 
print(main_model.fc2.weight[0,0:5])
after_acc_table=compare_local_and_merged_model_performance(number_of_slices=number_of_slices)
after_test_loss, after_test_accuracy = validation(main_model, test_dl, main_criterion)
file.write('\nafter training main model')
confusion_mat(main_model, test_dl)
# Out:
# none
# confusion matrix for normal scenario for slices : 5
# [[   0    0 7703    0    2]
#  [   0    0 5338    0    0]
#  [   0    0   11    0    0]
#  [   0    0  388    0    0]
#  [   0    0 1407    0    0]]
# tensor([-0.0464, -0.0442,  0.0016,  0.0068, -0.0213], grad_fn=<SliceBackward>)
# none
# confusion matrix for normal scenario for slices : 5
# [[7705    0    0    0    0]
#  [5338    0    0    0    0]
#  [  11    0    0    0    0]
#  [ 388    0    0    0    0]
#  [1407    0    0    0    0]]

# %%
print("Federated main model vs individual local models before FedAvg first iteration")
file.write('\nBefore training federated')
file.write('\n'+str(before_acc_table))
before_acc_table
# Out:
# Federated main model vs individual local models before FedAvg first iteration
#      sample  local_ind_model  merged_main_model
# 0  sample 0           0.8681             0.0007
# 1  sample 1           0.5192             0.0007
# 2  sample 2           0.5296             0.0007
# 3  sample 3           0.6056             0.0007
# 4  sample 4           0.5189             0.0007

# %%
print("Federated main model vs individual local models after FedAvg first iteration")
file.write('\nAfter training federated')
file.write('\n'+str(after_acc_table))
after_acc_table
# Out:
# Federated main model vs individual local models after FedAvg first iteration
#      sample  local_ind_model  merged_main_model
# 0  sample 0           0.8681             0.5189
# 1  sample 1           0.5192             0.5189
# 2  sample 2           0.5296             0.5189
# 3  sample 3           0.6056             0.5189
# 4  sample 4           0.5189             0.5189

# %% [markdown]
# **Federated main model vs centralized model before 1st iteration (on all test data)**
# Please be aware that the centralized model gets approximately %98 accuracy on all test data.

# %%
print("Before 1st iteration main model accuracy on all test data: {:7.4f}".format(before_test_accuracy))
print("After 1st iteration main model accuracy on all test data: {:7.4f}".format(after_test_accuracy))
print("Centralized model accuracy on all test data: {:7.4f}".format(central_test_accuracy))
# Out:
# Before 1st iteration main model accuracy on all test data:  0.0007
# After 1st iteration main model accuracy on all test data:  0.5189
# Centralized model accuracy on all test data:  0.8882

# %% [markdown]
# This is a single iteration, we can send the weights of the main model back to the nodes and repeat the above steps.
# Now let's check how the performance of the main model improves when we repeat the iteration 10 more times.

# %%
for i in range(100):
    model_dict=send_main_model_to_nodes_and_update_model_dict(main_model, model_dict, number_of_slices)
    start_train_end_node_process_print_some(number_of_slices, print_amount)
    main_model= set_averaged_weights_as_main_model_weights_and_update_main_model(main_model,model_dict, number_of_slices) 
    test_loss, test_accuracy = validation(main_model, test_dl, main_criterion)
    print("Iteration", str(i+2), ": main_model accuracy on all test data: {:7.4f}".format(test_accuracy))
# Out:
# Updating model :model0
# Updating model :model1
# Updating model :model2
# Updating model :model3
# Updating model :model4
# Federated learning for slice 1
# Subset 0
# epoch:   1 | train accuracy: 0.97459 | test accuracy: 0.86605
# epoch:   2 | train accuracy: 0.98501 | test accuracy: 0.86497
# epoch:   3 | train accuracy: 0.98735 | test accuracy: 0.86679
# epoch:   4 | train accuracy: 0.98914 | test accuracy: 0.85770
# epoch:   5 | train accuracy: 0.98942 | test accuracy: 0.87144
# epoch:   6 | train accuracy: 0.99001 | test accuracy: 0.87144
# epoch:   7 | train accuracy: 0.99115 | test accuracy: 0.87198
# epoch:   8 | train accuracy: 0.99070 | test accuracy: 0.86363
# epoch:   9 | train accuracy: 0.99176 | test accuracy: 0.87272
# epoch:  10 | train accuracy: 0.99217 | test accuracy: 0.86800
# epoch:  11 | train accuracy: 0.99233 | test accuracy: 0.87292
# epoch:  12 | train accuracy: 0.99224 | test accuracy: 0.85225
# epoch:  13 | train accuracy: 0.99295 | test accuracy: 0.87198
# epoch:  14 | train accuracy: 0.99285 | test accuracy: 0.86976
# epoch:  15 | train accuracy: 0.99305 | test accuracy: 0.87009
# epoch:  16 | train accuracy: 0.99350 | test accuracy: 0.86167
# epoch:  17 | train accuracy: 0.99295 | test accuracy: 0.87171
# epoch:  18 | train accuracy: 0.99353 | test accuracy: 0.87178
# epoch:  19 | train accuracy: 0.99352 | test accuracy: 0.86787
# epoch:  20 | train accuracy: 0.99369 | test accuracy: 0.87198
# Confusion matrix for model0
# confusion matrix for normal scenario for slices : 5
# [[7614   91    0    0    0]
#  [   4 5334    0    0    0]
#  [  11    0    0    0    0]
#  [ 346   42    0    0    0]
#  [ 761  646    0    0    0]]
# Federated learning for slice 2
# Subset 1
# epoch:   1 | train accuracy: 0.99234 | test accuracy: 0.51889
# epoch:   2 | train accuracy: 0.99363 | test accuracy: 0.51909
# epoch:   3 | train accuracy: 0.99498 | test accuracy: 0.51902
# epoch:   4 | train accuracy: 0.99549 | test accuracy: 0.51896
# epoch:   5 | train accuracy: 0.99543 | test accuracy: 0.51902
# epoch:   6 | train accuracy: 0.99543 | test accuracy: 0.51902
# epoch:   7 | train accuracy: 0.99549 | test accuracy: 0.51902
# epoch:   8 | train accuracy: 0.99536 | test accuracy: 0.51889
# epoch:   9 | train accuracy: 0.99549 | test accuracy: 0.51889
# epoch:  10 | train accuracy: 0.99543 | test accuracy: 0.51909
# epoch:  11 | train accuracy: 0.99556 | test accuracy: 0.51902
# epoch:  12 | train accuracy: 0.99549 | test accuracy: 0.51916
# epoch:  13 | train accuracy: 0.99549 | test accuracy: 0.51909
# epoch:  14 | train accuracy: 0.99556 | test accuracy: 0.51916
# epoch:  15 | train accuracy: 0.99556 | test accuracy: 0.51916
# epoch:  16 | train accuracy: 0.99556 | test accuracy: 0.51909
# epoch:  17 | train accuracy: 0.99549 | test accuracy: 0.51882
# epoch:  18 | train accuracy: 0.99562 | test accuracy: 0.51916
# epoch:  19 | train accuracy: 0.99562 | test accuracy: 0.51916
# epoch:  20 | train accuracy: 0.99549 | test accuracy: 0.51916
# Confusion matrix for model1
# confusion matrix for normal scenario for slices : 5
# [[7703    0    2    0    0]
#  [5338    0    0    0    0]
#  [   5    0    6    0    0]
#  [ 387    0    1    0    0]
#  [1407    0    0    0    0]]
# Federated learning for slice 3
# Subset 2
# epoch:   1 | train accuracy: 0.87906 | test accuracy: 0.50603
# epoch:   2 | train accuracy: 0.90285 | test accuracy: 0.52158
# epoch:   3 | train accuracy: 0.90378 | test accuracy: 0.51842
# epoch:   4 | train accuracy: 0.90731 | test accuracy: 0.48724
# epoch:   5 | train accuracy: 0.91083 | test accuracy: 0.53310
# epoch:   6 | train accuracy: 0.91130 | test accuracy: 0.53424
# epoch:   7 | train accuracy: 0.91529 | test accuracy: 0.53202
# epoch:   8 | train accuracy: 0.91400 | test accuracy: 0.52576
# epoch:   9 | train accuracy: 0.91426 | test accuracy: 0.52549
# epoch:  10 | train accuracy: 0.91825 | test accuracy: 0.52185
# epoch:  11 | train accuracy: 0.91877 | test accuracy: 0.52172
# epoch:  12 | train accuracy: 0.92001 | test accuracy: 0.49936
# epoch:  13 | train accuracy: 0.92053 | test accuracy: 0.53000
# epoch:  14 | train accuracy: 0.91960 | test accuracy: 0.52475
# epoch:  15 | train accuracy: 0.91918 | test accuracy: 0.52495
# epoch:  16 | train accuracy: 0.92120 | test accuracy: 0.51195
# epoch:  17 | train accuracy: 0.92302 | test accuracy: 0.51923
# epoch:  18 | train accuracy: 0.92198 | test accuracy: 0.52872
# epoch:  19 | train accuracy: 0.92115 | test accuracy: 0.50448
# epoch:  20 | train accuracy: 0.92364 | test accuracy: 0.53276
# Confusion matrix for model2
# confusion matrix for normal scenario for slices : 5
# [[7548    0    0  157    0]
#  [5322    0    0   16    0]
#  [   4    0    0    7    0]
#  [  25    0    0  363    0]
#  [1128    0    0  279    0]]
# Federated learning for slice 4
# Subset 3
# epoch:   1 | train accuracy: 0.96022 | test accuracy: 0.59607
# epoch:   2 | train accuracy: 0.97345 | test accuracy: 0.59815
# epoch:   3 | train accuracy: 0.97775 | test accuracy: 0.60314
# epoch:   4 | train accuracy: 0.97945 | test accuracy: 0.60523
# epoch:   5 | train accuracy: 0.98023 | test accuracy: 0.60563
# epoch:   6 | train accuracy: 0.98169 | test accuracy: 0.60152
# epoch:   7 | train accuracy: 0.98270 | test accuracy: 0.60193
# epoch:   8 | train accuracy: 0.98243 | test accuracy: 0.60516
# epoch:   9 | train accuracy: 0.98376 | test accuracy: 0.60105
# epoch:  10 | train accuracy: 0.98335 | test accuracy: 0.60570
# epoch:  11 | train accuracy: 0.98382 | test accuracy: 0.59681
# epoch:  12 | train accuracy: 0.98386 | test accuracy: 0.59869
# epoch:  13 | train accuracy: 0.98362 | test accuracy: 0.60186
# epoch:  14 | train accuracy: 0.98501 | test accuracy: 0.60603
# epoch:  15 | train accuracy: 0.98491 | test accuracy: 0.60550
# epoch:  16 | train accuracy: 0.98542 | test accuracy: 0.59681
# epoch:  17 | train accuracy: 0.98488 | test accuracy: 0.60691
# epoch:  18 | train accuracy: 0.98542 | test accuracy: 0.60853
# epoch:  19 | train accuracy: 0.98542 | test accuracy: 0.60576
# epoch:  20 | train accuracy: 0.98559 | test accuracy: 0.60415
# Confusion matrix for model3
# confusion matrix for normal scenario for slices : 5
# [[7589    0    0    0  116]
#  [ 316    0    0    0 5022]
#  [  10    0    0    0    1]
#  [ 160    0    0    0  228]
#  [  25    0    0    0 1382]]
# Federated learning for slice 5
# Subset 4
# epoch:   1 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   2 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   3 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   4 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   5 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   6 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   7 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   8 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   9 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  10 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  11 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  12 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  13 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  14 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  15 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  16 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  17 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  18 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  19 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  20 | train accuracy: 1.00000 | test accuracy: 0.51889
# Confusion matrix for model4
# confusion matrix for normal scenario for slices : 5
# [[7705    0    0    0    0]
#  [5338    0    0    0    0]
#  [  11    0    0    0    0]
#  [ 388    0    0    0    0]
#  [1407    0    0    0    0]]
# Iteration 2 : main_model accuracy on all test data:  0.7990
# Updating model :model0
# Updating model :model1
# Updating model :model2
# Updating model :model3
# Updating model :model4
# Federated learning for slice 1
# Subset 0
# epoch:   1 | train accuracy: 0.98400 | test accuracy: 0.86127
# epoch:   2 | train accuracy: 0.98894 | test accuracy: 0.86962
# epoch:   3 | train accuracy: 0.98993 | test accuracy: 0.87191
# epoch:   4 | train accuracy: 0.99119 | test accuracy: 0.86787
# epoch:   5 | train accuracy: 0.99141 | test accuracy: 0.86497
# epoch:   6 | train accuracy: 0.99173 | test accuracy: 0.86794
# epoch:   7 | train accuracy: 0.99222 | test accuracy: 0.87198
# epoch:   8 | train accuracy: 0.99203 | test accuracy: 0.83608
# epoch:   9 | train accuracy: 0.99214 | test accuracy: 0.87124
# epoch:  10 | train accuracy: 0.99298 | test accuracy: 0.87036
# epoch:  11 | train accuracy: 0.99263 | test accuracy: 0.87332
# epoch:  12 | train accuracy: 0.99260 | test accuracy: 0.87258
# epoch:  13 | train accuracy: 0.99331 | test accuracy: 0.86740
# epoch:  14 | train accuracy: 0.99355 | test accuracy: 0.87339
# epoch:  15 | train accuracy: 0.99328 | test accuracy: 0.87272
# epoch:  16 | train accuracy: 0.99400 | test accuracy: 0.86140
# epoch:  17 | train accuracy: 0.99435 | test accuracy: 0.87359
# epoch:  18 | train accuracy: 0.99410 | test accuracy: 0.87413
# epoch:  19 | train accuracy: 0.99346 | test accuracy: 0.86747
# epoch:  20 | train accuracy: 0.99365 | test accuracy: 0.87319
# Confusion matrix for model0
# confusion matrix for normal scenario for slices : 5
# [[7635   70    0    0    0]
#  [   7 5331    0    0    0]
#  [  11    0    0    0    0]
#  [ 376   12    0    0    0]
#  [ 782  625    0    0    0]]
# Federated learning for slice 2
# Subset 1
# epoch:   1 | train accuracy: 0.99272 | test accuracy: 0.80019
# epoch:   2 | train accuracy: 0.99485 | test accuracy: 0.51902
# epoch:   3 | train accuracy: 0.99543 | test accuracy: 0.51896
# epoch:   4 | train accuracy: 0.99536 | test accuracy: 0.51902
# epoch:   5 | train accuracy: 0.99549 | test accuracy: 0.51902
# epoch:   6 | train accuracy: 0.99556 | test accuracy: 0.51909
# epoch:   7 | train accuracy: 0.99556 | test accuracy: 0.51882
# epoch:   8 | train accuracy: 0.99536 | test accuracy: 0.51902
# epoch:   9 | train accuracy: 0.99556 | test accuracy: 0.51909
# epoch:  10 | train accuracy: 0.99562 | test accuracy: 0.51909
# epoch:  11 | train accuracy: 0.99549 | test accuracy: 0.51889
# epoch:  12 | train accuracy: 0.99569 | test accuracy: 0.51916
# epoch:  13 | train accuracy: 0.99569 | test accuracy: 0.51916
# epoch:  14 | train accuracy: 0.99581 | test accuracy: 0.51902
# epoch:  15 | train accuracy: 0.99581 | test accuracy: 0.51916
# epoch:  16 | train accuracy: 0.99601 | test accuracy: 0.51916
# epoch:  17 | train accuracy: 0.99588 | test accuracy: 0.51916
# epoch:  18 | train accuracy: 0.99575 | test accuracy: 0.51869
# epoch:  19 | train accuracy: 0.99588 | test accuracy: 0.51909
# epoch:  20 | train accuracy: 0.99594 | test accuracy: 0.51754
# Confusion matrix for model1
# confusion matrix for normal scenario for slices : 5
# [[7678    0   27    0    0]
#  [5136    0  202    0    0]
#  [   4    0    7    0    0]
#  [ 377    0   11    0    0]
#  [1287    0  120    0    0]]
# Federated learning for slice 3
# Subset 2
# epoch:   1 | train accuracy: 0.90062 | test accuracy: 0.51997
# epoch:   2 | train accuracy: 0.90819 | test accuracy: 0.51458
# epoch:   3 | train accuracy: 0.90938 | test accuracy: 0.52536
# epoch:   4 | train accuracy: 0.91685 | test accuracy: 0.51849
# epoch:   5 | train accuracy: 0.91291 | test accuracy: 0.53270
# epoch:   6 | train accuracy: 0.91752 | test accuracy: 0.52212
# epoch:   7 | train accuracy: 0.91908 | test accuracy: 0.52293
# epoch:   8 | train accuracy: 0.92182 | test accuracy: 0.48778
# epoch:   9 | train accuracy: 0.92162 | test accuracy: 0.50710
# epoch:  10 | train accuracy: 0.92136 | test accuracy: 0.53236
# epoch:  11 | train accuracy: 0.92229 | test accuracy: 0.49882
# epoch:  12 | train accuracy: 0.92141 | test accuracy: 0.52933
# epoch:  13 | train accuracy: 0.92654 | test accuracy: 0.53492
# epoch:  14 | train accuracy: 0.92032 | test accuracy: 0.52771
# epoch:  15 | train accuracy: 0.92416 | test accuracy: 0.51094
# epoch:  16 | train accuracy: 0.92452 | test accuracy: 0.53613
# epoch:  17 | train accuracy: 0.92488 | test accuracy: 0.53034
# epoch:  18 | train accuracy: 0.92753 | test accuracy: 0.51977
# epoch:  19 | train accuracy: 0.92685 | test accuracy: 0.51350
# epoch:  20 | train accuracy: 0.92773 | test accuracy: 0.52367
# Confusion matrix for model2
# confusion matrix for normal scenario for slices : 5
# [[7420    0    0  285    0]
#  [5231    0    0  107    0]
#  [   4    0    0    7    0]
#  [  32    0    0  356    0]
#  [1038    0    0  369    0]]
# Federated learning for slice 4
# Subset 3
# epoch:   1 | train accuracy: 0.97233 | test accuracy: 0.60381
# epoch:   2 | train accuracy: 0.98016 | test accuracy: 0.60442
# epoch:   3 | train accuracy: 0.98142 | test accuracy: 0.59782
# epoch:   4 | train accuracy: 0.98230 | test accuracy: 0.60220
# epoch:   5 | train accuracy: 0.98379 | test accuracy: 0.60550
# epoch:   6 | train accuracy: 0.98365 | test accuracy: 0.60482
# epoch:   7 | train accuracy: 0.98437 | test accuracy: 0.60395
# epoch:   8 | train accuracy: 0.98542 | test accuracy: 0.60516
# epoch:   9 | train accuracy: 0.98471 | test accuracy: 0.60590
# epoch:  10 | train accuracy: 0.98528 | test accuracy: 0.60462
# epoch:  11 | train accuracy: 0.98579 | test accuracy: 0.59896
# epoch:  12 | train accuracy: 0.98566 | test accuracy: 0.60624
# epoch:  13 | train accuracy: 0.98596 | test accuracy: 0.60550
# epoch:  14 | train accuracy: 0.98511 | test accuracy: 0.60321
# epoch:  15 | train accuracy: 0.98620 | test accuracy: 0.60704
# epoch:  16 | train accuracy: 0.98660 | test accuracy: 0.60179
# epoch:  17 | train accuracy: 0.98654 | test accuracy: 0.60502
# epoch:  18 | train accuracy: 0.98688 | test accuracy: 0.60758
# epoch:  19 | train accuracy: 0.98681 | test accuracy: 0.60785
# epoch:  20 | train accuracy: 0.98793 | test accuracy: 0.60603
# Confusion matrix for model3
# confusion matrix for normal scenario for slices : 5
# [[7618    0    0    0   87]
#  [ 307    0    0    0 5031]
#  [   9    0    0    0    2]
#  [ 160    0    0    0  228]
#  [  26    0    0    0 1381]]
# Federated learning for slice 5
# Subset 4
# epoch:   1 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   2 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   3 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   4 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   5 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   6 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   7 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   8 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   9 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  10 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  11 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  12 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  13 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  14 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  15 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  16 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  17 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  18 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  19 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  20 | train accuracy: 1.00000 | test accuracy: 0.51889
# Confusion matrix for model4
# confusion matrix for normal scenario for slices : 5
# [[7705    0    0    0    0]
#  [5338    0    0    0    0]
#  [  11    0    0    0    0]
#  [ 388    0    0    0    0]
#  [1407    0    0    0    0]]
# Iteration 3 : main_model accuracy on all test data:  0.8068
# Updating model :model0
# Updating model :model1
# Updating model :model2
# Updating model :model3
# Updating model :model4
# Federated learning for slice 1
# Subset 0
# epoch:   1 | train accuracy: 0.98701 | test accuracy: 0.87238
# epoch:   2 | train accuracy: 0.99073 | test accuracy: 0.87002
# epoch:   3 | train accuracy: 0.99138 | test accuracy: 0.87104
# epoch:   4 | train accuracy: 0.99203 | test accuracy: 0.86848
# epoch:   5 | train accuracy: 0.99201 | test accuracy: 0.87090
# epoch:   6 | train accuracy: 0.99254 | test accuracy: 0.87225
# epoch:   7 | train accuracy: 0.99296 | test accuracy: 0.84578
# epoch:   8 | train accuracy: 0.99365 | test accuracy: 0.87272
# epoch:   9 | train accuracy: 0.99282 | test accuracy: 0.87279
# epoch:  10 | train accuracy: 0.99331 | test accuracy: 0.86854
# epoch:  11 | train accuracy: 0.99405 | test accuracy: 0.87164
# epoch:  12 | train accuracy: 0.99430 | test accuracy: 0.86976
# epoch:  13 | train accuracy: 0.99334 | test accuracy: 0.87285
# epoch:  14 | train accuracy: 0.99435 | test accuracy: 0.87339
# epoch:  15 | train accuracy: 0.99440 | test accuracy: 0.87144
# epoch:  16 | train accuracy: 0.99421 | test accuracy: 0.87178
# epoch:  17 | train accuracy: 0.99449 | test accuracy: 0.87393
# epoch:  18 | train accuracy: 0.99423 | test accuracy: 0.86430
# epoch:  19 | train accuracy: 0.99465 | test accuracy: 0.87386
# epoch:  20 | train accuracy: 0.99448 | test accuracy: 0.87386
# Confusion matrix for model0
# confusion matrix for normal scenario for slices : 5
# [[7644   61    0    0    0]
#  [   6 5332    0    0    0]
#  [  11    0    0    0    0]
#  [ 369   19    0    0    0]
#  [ 808  599    0    0    0]]
# Federated learning for slice 2
# Subset 1
# epoch:   1 | train accuracy: 0.99343 | test accuracy: 0.81649
# epoch:   2 | train accuracy: 0.99549 | test accuracy: 0.78450
# epoch:   3 | train accuracy: 0.99549 | test accuracy: 0.70847
# epoch:   4 | train accuracy: 0.99594 | test accuracy: 0.63863
# epoch:   5 | train accuracy: 0.99569 | test accuracy: 0.57088
# epoch:   6 | train accuracy: 0.99556 | test accuracy: 0.51896
# epoch:   7 | train accuracy: 0.99556 | test accuracy: 0.51916
# epoch:   8 | train accuracy: 0.99581 | test accuracy: 0.51916
# epoch:   9 | train accuracy: 0.99575 | test accuracy: 0.51916
# epoch:  10 | train accuracy: 0.99601 | test accuracy: 0.51896
# epoch:  11 | train accuracy: 0.99594 | test accuracy: 0.51916
# epoch:  12 | train accuracy: 0.99588 | test accuracy: 0.51916
# epoch:  13 | train accuracy: 0.99607 | test accuracy: 0.51916
# epoch:  14 | train accuracy: 0.99601 | test accuracy: 0.51916
# epoch:  15 | train accuracy: 0.99627 | test accuracy: 0.51801
# epoch:  16 | train accuracy: 0.99588 | test accuracy: 0.51916
# epoch:  17 | train accuracy: 0.99607 | test accuracy: 0.51916
# epoch:  18 | train accuracy: 0.99607 | test accuracy: 0.51916
# epoch:  19 | train accuracy: 0.99607 | test accuracy: 0.51882
# epoch:  20 | train accuracy: 0.99633 | test accuracy: 0.51909
# Confusion matrix for model1
# confusion matrix for normal scenario for slices : 5
# [[7702    0    3    0    0]
#  [1491    0 3847    0    0]
#  [   5    0    6    0    0]
#  [ 387    0    1    0    0]
#  [1149    0  258    0    0]]
# Federated learning for slice 3
# Subset 2
# epoch:   1 | train accuracy: 0.90358 | test accuracy: 0.52872
# epoch:   2 | train accuracy: 0.91586 | test accuracy: 0.53263
# epoch:   3 | train accuracy: 0.91389 | test accuracy: 0.51667
# epoch:   4 | train accuracy: 0.91897 | test accuracy: 0.48347
# epoch:   5 | train accuracy: 0.91856 | test accuracy: 0.53364
# epoch:   6 | train accuracy: 0.92079 | test accuracy: 0.52657
# epoch:   7 | train accuracy: 0.92006 | test accuracy: 0.50980
# epoch:   8 | train accuracy: 0.92276 | test accuracy: 0.52913
# epoch:   9 | train accuracy: 0.92198 | test accuracy: 0.51350
# epoch:  10 | train accuracy: 0.92084 | test accuracy: 0.53492
# epoch:  11 | train accuracy: 0.92240 | test accuracy: 0.53438
# epoch:  12 | train accuracy: 0.92348 | test accuracy: 0.50542
# epoch:  13 | train accuracy: 0.92551 | test accuracy: 0.53357
# epoch:  14 | train accuracy: 0.92535 | test accuracy: 0.53162
# epoch:  15 | train accuracy: 0.92618 | test accuracy: 0.52791
# epoch:  16 | train accuracy: 0.92499 | test accuracy: 0.52589
# epoch:  17 | train accuracy: 0.92742 | test accuracy: 0.53317
# epoch:  18 | train accuracy: 0.92836 | test accuracy: 0.53438
# epoch:  19 | train accuracy: 0.93012 | test accuracy: 0.49788
# epoch:  20 | train accuracy: 0.92727 | test accuracy: 0.51290
# Confusion matrix for model2
# confusion matrix for normal scenario for slices : 5
# [[7241    0    0  464    0]
#  [5196    0    0  142    0]
#  [   2    0    0    9    0]
#  [  13    0    0  375    0]
#  [ 829    0    0  578    0]]
# Federated learning for slice 4
# Subset 3
# epoch:   1 | train accuracy: 0.97569 | test accuracy: 0.59930
# epoch:   2 | train accuracy: 0.98321 | test accuracy: 0.60536
# epoch:   3 | train accuracy: 0.98396 | test accuracy: 0.59708
# epoch:   4 | train accuracy: 0.98389 | test accuracy: 0.60711
# epoch:   5 | train accuracy: 0.98545 | test accuracy: 0.60651
# epoch:   6 | train accuracy: 0.98566 | test accuracy: 0.60725
# epoch:   7 | train accuracy: 0.98582 | test accuracy: 0.60475
# epoch:   8 | train accuracy: 0.98535 | test accuracy: 0.60644
# epoch:   9 | train accuracy: 0.98637 | test accuracy: 0.60583
# epoch:  10 | train accuracy: 0.98640 | test accuracy: 0.60792
# epoch:  11 | train accuracy: 0.98728 | test accuracy: 0.60543
# epoch:  12 | train accuracy: 0.98667 | test accuracy: 0.60677
# epoch:  13 | train accuracy: 0.98677 | test accuracy: 0.60603
# epoch:  14 | train accuracy: 0.98654 | test accuracy: 0.60597
# epoch:  15 | train accuracy: 0.98762 | test accuracy: 0.60408
# epoch:  16 | train accuracy: 0.98644 | test accuracy: 0.60523
# epoch:  17 | train accuracy: 0.98793 | test accuracy: 0.60664
# epoch:  18 | train accuracy: 0.98718 | test accuracy: 0.60610
# epoch:  19 | train accuracy: 0.98884 | test accuracy: 0.60698
# epoch:  20 | train accuracy: 0.98806 | test accuracy: 0.60603
# Confusion matrix for model3
# confusion matrix for normal scenario for slices : 5
# [[7608    0    0    0   97]
#  [ 293    0    0    0 5045]
#  [   9    0    0    0    2]
#  [ 165    0    0    0  223]
#  [  16    0    0    0 1391]]
# Federated learning for slice 5
# Subset 4
# epoch:   1 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   2 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   3 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   4 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   5 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   6 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   7 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   8 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:   9 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  10 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  11 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  12 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  13 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  14 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  15 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  16 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  17 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  18 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  19 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  20 | train accuracy: 1.00000 | test accuracy: 0.51889
# Confusion matrix for model4
# confusion matrix for normal scenario for slices : 5
# [[7705    0    0    0    0]
#  [5338    0    0    0    0]
#  [  11    0    0    0    0]
#  [ 388    0    0    0    0]
#  [1407    0    0    0    0]]
# Iteration 4 : main_model accuracy on all test data:  0.8192
# Updating model :model0
# Updating model :model1
# Updating model :model2
# Updating model :model3
# Updating model :model4
# Federated learning for slice 1
# Subset 0
# epoch:   1 | train accuracy: 0.99006 | test accuracy: 0.86969
# epoch:   2 | train accuracy: 0.99253 | test accuracy: 0.87205
# epoch:   3 | train accuracy: 0.99276 | test accuracy: 0.86706
# epoch:   4 | train accuracy: 0.99233 | test accuracy: 0.87272
# epoch:   5 | train accuracy: 0.99324 | test accuracy: 0.87036
# epoch:   6 | train accuracy: 0.99360 | test accuracy: 0.87252
# epoch:   7 | train accuracy: 0.99305 | test accuracy: 0.86915
# epoch:   8 | train accuracy: 0.99424 | test accuracy: 0.87272
# epoch:   9 | train accuracy: 0.99400 | test accuracy: 0.87386
# epoch:  10 | train accuracy: 0.99385 | test accuracy: 0.87279
# epoch:  11 | train accuracy: 0.99452 | test accuracy: 0.87386
# epoch:  12 | train accuracy: 0.99465 | test accuracy: 0.87386
# epoch:  13 | train accuracy: 0.99391 | test accuracy: 0.86699
# epoch:  14 | train accuracy: 0.99433 | test accuracy: 0.86511
# epoch:  15 | train accuracy: 0.99443 | test accuracy: 0.87272
# epoch:  16 | train accuracy: 0.99490 | test accuracy: 0.87238
# epoch:  17 | train accuracy: 0.99453 | test accuracy: 0.87205
# epoch:  18 | train accuracy: 0.99468 | test accuracy: 0.87285
# epoch:  19 | train accuracy: 0.99474 | test accuracy: 0.87380
# epoch:  20 | train accuracy: 0.99555 | test accuracy: 0.87124
# Confusion matrix for model0
# confusion matrix for normal scenario for slices : 5
# [[7604  101    0    0    0]
#  [   5 5333    0    0    0]
#  [  11    0    0    0    0]
#  [ 356   32    0    0    0]
#  [ 470  937    0    0    0]]
# Federated learning for slice 2
# Subset 1
# epoch:   1 | train accuracy: 0.99408 | test accuracy: 0.86161
# epoch:   2 | train accuracy: 0.99575 | test accuracy: 0.79911
# epoch:   3 | train accuracy: 0.99562 | test accuracy: 0.78975
# epoch:   4 | train accuracy: 0.99594 | test accuracy: 0.77709
# epoch:   5 | train accuracy: 0.99601 | test accuracy: 0.76328
# epoch:   6 | train accuracy: 0.99594 | test accuracy: 0.74672
# epoch:   7 | train accuracy: 0.99575 | test accuracy: 0.70389
# epoch:   8 | train accuracy: 0.99601 | test accuracy: 0.67803
# epoch:   9 | train accuracy: 0.99607 | test accuracy: 0.65775
# epoch:  10 | train accuracy: 0.99581 | test accuracy: 0.63816
# epoch:  11 | train accuracy: 0.99607 | test accuracy: 0.61412
# epoch:  12 | train accuracy: 0.99614 | test accuracy: 0.57856
# epoch:  13 | train accuracy: 0.99607 | test accuracy: 0.52199
# epoch:  14 | train accuracy: 0.99594 | test accuracy: 0.51902
# epoch:  15 | train accuracy: 0.99627 | test accuracy: 0.51882
# epoch:  16 | train accuracy: 0.99607 | test accuracy: 0.51916
# epoch:  17 | train accuracy: 0.99639 | test accuracy: 0.51902
# epoch:  18 | train accuracy: 0.99627 | test accuracy: 0.51909
# epoch:  19 | train accuracy: 0.99614 | test accuracy: 0.51862
# epoch:  20 | train accuracy: 0.99614 | test accuracy: 0.51916
# Confusion matrix for model1
# confusion matrix for normal scenario for slices : 5
# [[7703    0    2    0    0]
#  [1601    0 3737    0    0]
#  [   5    0    6    0    0]
#  [ 387    0    1    0    0]
#  [1161    0  246    0    0]]
# Federated learning for slice 3
# Subset 2
# epoch:   1 | train accuracy: 0.90487 | test accuracy: 0.49929
# epoch:   2 | train accuracy: 0.91846 | test accuracy: 0.52475
# epoch:   3 | train accuracy: 0.91783 | test accuracy: 0.52866
# epoch:   4 | train accuracy: 0.92022 | test accuracy: 0.49835
# epoch:   5 | train accuracy: 0.92177 | test accuracy: 0.50697
# epoch:   6 | train accuracy: 0.92250 | test accuracy: 0.49384
# epoch:   7 | train accuracy: 0.92442 | test accuracy: 0.52549
# epoch:   8 | train accuracy: 0.92561 | test accuracy: 0.50239
# epoch:   9 | train accuracy: 0.92561 | test accuracy: 0.53108
# epoch:  10 | train accuracy: 0.92773 | test accuracy: 0.52381
# epoch:  11 | train accuracy: 0.92773 | test accuracy: 0.52623
# epoch:  12 | train accuracy: 0.92758 | test accuracy: 0.53350
# epoch:  13 | train accuracy: 0.92846 | test accuracy: 0.52832
# epoch:  14 | train accuracy: 0.93038 | test accuracy: 0.53404
# epoch:  15 | train accuracy: 0.93136 | test accuracy: 0.52987
# epoch:  16 | train accuracy: 0.93302 | test accuracy: 0.48677
# epoch:  17 | train accuracy: 0.92976 | test accuracy: 0.52866
# epoch:  18 | train accuracy: 0.93007 | test accuracy: 0.50987
# epoch:  19 | train accuracy: 0.93276 | test accuracy: 0.53438
# epoch:  20 | train accuracy: 0.93214 | test accuracy: 0.52872
# Confusion matrix for model2
# confusion matrix for normal scenario for slices : 5
# [[7508    0    0  197    0]
#  [5221    0    0  117    0]
#  [   4    0    0    7    0]
#  [  45    0    0  343    0]
#  [1172    0    0  235    0]]
# Federated learning for slice 4
# Subset 3
# epoch:   1 | train accuracy: 0.97945 | test accuracy: 0.59425
# epoch:   2 | train accuracy: 0.98420 | test accuracy: 0.60502
# epoch:   3 | train accuracy: 0.98460 | test accuracy: 0.60529
# epoch:   4 | train accuracy: 0.98606 | test accuracy: 0.60610
# epoch:   5 | train accuracy: 0.98616 | test accuracy: 0.60718
# epoch:   6 | train accuracy: 0.98718 | test accuracy: 0.60799
# epoch:   7 | train accuracy: 0.98681 | test accuracy: 0.60772
# epoch:   8 | train accuracy: 0.98745 | test accuracy: 0.60570
# epoch:   9 | train accuracy: 0.98715 | test accuracy: 0.60502
# epoch:  10 | train accuracy: 0.98698 | test accuracy: 0.60583
# epoch:  11 | train accuracy: 0.98772 | test accuracy: 0.60563
# epoch:  12 | train accuracy: 0.98837 | test accuracy: 0.60839
# epoch:  13 | train accuracy: 0.98806 | test accuracy: 0.60502
# epoch:  14 | train accuracy: 0.98800 | test accuracy: 0.60469
# epoch:  15 | train accuracy: 0.98837 | test accuracy: 0.60529
# epoch:  16 | train accuracy: 0.98813 | test accuracy: 0.60644
# epoch:  17 | train accuracy: 0.98867 | test accuracy: 0.60630
# epoch:  18 | train accuracy: 0.98891 | test accuracy: 0.60772
# epoch:  19 | train accuracy: 0.98857 | test accuracy: 0.60610
# epoch:  20 | train accuracy: 0.98830 | test accuracy: 0.60772
# Confusion matrix for model3
# confusion matrix for normal scenario for slices : 5
# [[7631    0    0    0   74]
#  [ 297    0    0    0 5041]
#  [   9    0    0    0    2]
#  [ 242    0    0    0  146]
#  [  14    0    0    0 1393]]
# Federated learning for slice 5
# Subset 4
# epoch:   1 | train accuracy: 0.99987 | test accuracy: 0.56118
# epoch:   2 | train accuracy: 1.00000 | test accuracy: 0.52185
# epoch:   3 | train accuracy: 1.00000 | test accuracy: 0.52004
# epoch:   4 | train accuracy: 1.00000 | test accuracy: 0.51950
# epoch:   5 | train accuracy: 1.00000 | test accuracy: 0.51936
# epoch:   6 | train accuracy: 1.00000 | test accuracy: 0.51902
# epoch:   7 | train accuracy: 1.00000 | test accuracy: 0.51902
# epoch:   8 | train accuracy: 1.00000 | test accuracy: 0.51896
# epoch:   9 | train accuracy: 1.00000 | test accuracy: 0.51896
# epoch:  10 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  11 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  12 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  13 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  14 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  15 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  16 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  17 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  18 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  19 | train accuracy: 1.00000 | test accuracy: 0.51889
# epoch:  20 | train accuracy: 1.00000 | test accuracy: 0.51889
# Confusion matrix for model4
# confusion matrix for normal scenario for slices : 5
# [[7705    0    0    0    0]
#  [5338    0    0    0    0]
#  [  11    0    0    0    0]
#  [ 388    0    0    0    0]
#  [1407    0    0    0    0]]
# Iteration 5 : main_model accuracy on all test data:  0.8190
# Updating model :model0
# Updating model :model1
# Updating model :model2
# Updating model :model3
# Updating model :model4
# Federated learning for slice 1
# Subset 0
# epoch:   1 | train accuracy: 0.99074 | test accuracy: 0.86996
# epoch:   2 | train accuracy: 0.99311 | test accuracy: 0.87299
# epoch:   3 | train accuracy: 0.99308 | test accuracy: 0.87231
# epoch:   4 | train accuracy: 0.99349 | test accuracy: 0.87191
# epoch:   5 | train accuracy: 0.99417 | test accuracy: 0.87326
# epoch:   6 | train accuracy: 0.99413 | test accuracy: 0.87151
# epoch:   7 | train accuracy: 0.99430 | test accuracy: 0.87306
# epoch:   8 | train accuracy: 0.99437 | test accuracy: 0.87319
# epoch:   9 | train accuracy: 0.99451 | test accuracy: 0.87245
# epoch:  10 | train accuracy: 0.99429 | test accuracy: 0.87319
# epoch:  11 | train accuracy: 0.99481 | test accuracy: 0.87191
# epoch:  12 | train accuracy: 0.99446 | test accuracy: 0.87272
# epoch:  13 | train accuracy: 0.99496 | test accuracy: 0.87306
# epoch:  14 | train accuracy: 0.99487 | test accuracy: 0.87043
# epoch:  15 | train accuracy: 0.99515 | test accuracy: 0.87090
# epoch:  16 | train accuracy: 0.99494 | test accuracy: 0.86821
# epoch:  17 | train accuracy: 0.99567 | test accuracy: 0.87339
# epoch:  18 | train accuracy: 0.99526 | test accuracy: 0.87366
# epoch:  19 | train accuracy: 0.99538 | test accuracy: 0.86922
# epoch:  20 | train accuracy: 0.99533 | test accuracy: 0.87386
# Confusion matrix for model0
# confusion matrix for normal scenario for slices : 5
# [[7653   52    0    0    0]
#  [  15 5323    0    0    0]
#  [  11    0    0    0    0]
#  [ 367   21    0    0    0]
#  [ 813  594    0    0    0]]
# Federated learning for slice 2
# Subset 1
# epoch:   1 | train accuracy: 0.99466 | test accuracy: 0.85804
# epoch:   2 | train accuracy: 0.99569 | test accuracy: 0.81399
# epoch:   3 | train accuracy: 0.99569 | test accuracy: 0.80248
# epoch:   4 | train accuracy: 0.99601 | test accuracy: 0.79433
# epoch:   5 | train accuracy: 0.99594 | test accuracy: 0.78968
# epoch:   6 | train accuracy: 0.99607 | test accuracy: 0.78369
# epoch:   7 | train accuracy: 0.99575 | test accuracy: 0.77655
# epoch:   8 | train accuracy: 0.99614 | test accuracy: 0.77487
# epoch:   9 | train accuracy: 0.99620 | test accuracy: 0.76086
# epoch:  10 | train accuracy: 0.99581 | test accuracy: 0.75291
# epoch:  11 | train accuracy: 0.99620 | test accuracy: 0.73998
# epoch:  12 | train accuracy: 0.99607 | test accuracy: 0.71735
# epoch:  13 | train accuracy: 0.99607 | test accuracy: 0.71163
# epoch:  14 | train accuracy: 0.99601 | test accuracy: 0.68678
# epoch:  15 | train accuracy: 0.99620 | test accuracy: 0.66860
# epoch:  16 | train accuracy: 0.99614 | test accuracy: 0.65654
# epoch:  17 | train accuracy: 0.99646 | test accuracy: 0.64900
# epoch:  18 | train accuracy: 0.99614 | test accuracy: 0.63695
# epoch:  19 | train accuracy: 0.99620 | test accuracy: 0.62516
# epoch:  20 | train accuracy: 0.99581 | test accuracy: 0.55829
# Confusion matrix for model1
# confusion matrix for normal scenario for slices : 5
# [[7703    0    2    0    0]
#  [1857  519 2962    0    0]
#  [   5    0    6    0    0]
#  [ 387    0    1    0    0]
#  [1128    5  212    0   62]]
# Federated learning for slice 3
# Subset 2
# epoch:   1 | train accuracy: 0.90907 | test accuracy: 0.70651
# epoch:   2 | train accuracy: 0.92120 | test accuracy: 0.65459
# epoch:   3 | train accuracy: 0.92519 | test accuracy: 0.52859
# epoch:   4 | train accuracy: 0.92276 | test accuracy: 0.53249
# epoch:   5 | train accuracy: 0.92385 | test accuracy: 0.53398
# epoch:   6 | train accuracy: 0.92379 | test accuracy: 0.51471
# epoch:   7 | train accuracy: 0.92893 | test accuracy: 0.52616
# epoch:   8 | train accuracy: 0.92789 | test accuracy: 0.52663
# epoch:   9 | train accuracy: 0.92939 | test accuracy: 0.48872
# epoch:  10 | train accuracy: 0.92830 | test accuracy: 0.52078
# epoch:  11 | train accuracy: 0.93059 | test accuracy: 0.51876
# epoch:  12 | train accuracy: 0.93162 | test accuracy: 0.53424
# epoch:  13 | train accuracy: 0.93027 | test accuracy: 0.51572
# epoch:  14 | train accuracy: 0.93090 | test accuracy: 0.53128
# epoch:  15 | train accuracy: 0.93323 | test accuracy: 0.47478
# epoch:  16 | train accuracy: 0.93183 | test accuracy: 0.52152
# epoch:  17 | train accuracy: 0.93209 | test accuracy: 0.51768
# epoch:  18 | train accuracy: 0.93064 | test accuracy: 0.52232
# epoch:  19 | train accuracy: 0.93437 | test accuracy: 0.53061
# epoch:  20 | train accuracy: 0.93354 | test accuracy: 0.52354
# Confusion matrix for model2
# confusion matrix for normal scenario for slices : 5
# [[7406    0    0  299    0]
#  [4758    0    0  580    0]
#  [   4    0    0    7    0]
#  [  20    0    0  368    0]
#  [ 523    0    0  884    0]]
# Federated learning for slice 4
# Subset 3
# epoch:   1 | train accuracy: 0.98030 | test accuracy: 0.60630
# epoch:   2 | train accuracy: 0.98572 | test accuracy: 0.60543
# epoch:   3 | train accuracy: 0.98667 | test accuracy: 0.60482
# epoch:   4 | train accuracy: 0.98681 | test accuracy: 0.60536
# epoch:   5 | train accuracy: 0.98816 | test accuracy: 0.60698
# epoch:   6 | train accuracy: 0.98806 | test accuracy: 0.60159
# epoch:   7 | train accuracy: 0.98783 | test accuracy: 0.60213
# epoch:   8 | train accuracy: 0.98800 | test accuracy: 0.60327
# epoch:   9 | train accuracy: 0.98827 | test accuracy: 0.60664
# epoch:  10 | train accuracy: 0.98847 | test accuracy: 0.60846
# epoch:  11 | train accuracy: 0.98854 | test accuracy: 0.60651
# epoch:  12 | train accuracy: 0.98901 | test accuracy: 0.60691
# epoch:  13 | train accuracy: 0.98959 | test accuracy: 0.60603
# epoch:  14 | train accuracy: 0.98932 | test accuracy: 0.60826
# epoch:  15 | train accuracy: 0.98928 | test accuracy: 0.60657
# epoch:  16 | train accuracy: 0.98925 | test accuracy: 0.60900
# epoch:  17 | train accuracy: 0.98888 | test accuracy: 0.60738
# epoch:  18 | train accuracy: 0.98922 | test accuracy: 0.59762
# epoch:  19 | train accuracy: 0.98966 | test accuracy: 0.59512
# epoch:  20 | train accuracy: 0.98962 | test accuracy: 0.60859
# Confusion matrix for model3
# confusion matrix for normal scenario for slices : 5
# [[7653    0    0    0   52]
#  [ 304    0    0    0 5034]
#  [  10    0    0    0    1]
#  [ 316    0    0    0   72]
#  [  23    0    0    0 1384]]
# Federated learning for slice 5
# Subset 4
# epoch:   1 | train accuracy: 0.99981 | test accuracy: 0.52515
# epoch:   2 | train accuracy: 1.00000 | test accuracy: 0.52300
# epoch:   3 | train accuracy: 1.00000 | test accuracy: 0.52239
# epoch:   4 | train accuracy: 1.00000 | test accuracy: 0.52145
# epoch:   5 | train accuracy: 1.00000 | test accuracy: 0.52098
# epoch:   6 | train accuracy: 1.00000 | test accuracy: 0.52078
# epoch:   7 | train accuracy: 1.00000 | test accuracy: 0.52051
# epoch:   8 | train accuracy: 1.00000 | test accuracy: 0.52017
# epoch:   9 | train accuracy: 1.00000 | test accuracy: 0.52004
# epoch:  10 | train accuracy: 1.00000 | test accuracy: 0.51990
# epoch:  11 | train accuracy: 1.00000 | test accuracy: 0.51990
# epoch:  12 | train accuracy: 1.00000 | test accuracy: 0.51983
# epoch:  13 | train accuracy: 1.00000 | test accuracy: 0.51970
# epoch:  14 | train accuracy: 1.00000 | test accuracy: 0.51970
# epoch:  15 | train accuracy: 1.00000 | test accuracy: 0.51963
# epoch:  16 | train accuracy: 1.00000 | test accuracy: 0.51950
# epoch:  17 | train accuracy: 1.00000 | test accuracy: 0.51943
# epoch:  18 | train accuracy: 1.00000 | test accuracy: 0.51936
# epoch:  19 | train accuracy: 1.00000 | test accuracy: 0.51916
# epoch:  20 | train accuracy: 1.00000 | test accuracy: 0.51909
# Confusion matrix for model4
# confusion matrix for normal scenario for slices : 5
# [[7705    0    0    0    0]
#  [5335    3    0    0    0]
#  [  11    0    0    0    0]
#  [ 388    0    0    0    0]
#  [1405    2    0    0    0]]
# Iteration 6 : main_model accuracy on all test data:  0.8345
# Updating model :model0
# Updating model :model1
# Updating model :model2
# Updating model :model3
# Updating model :model4
# Federated learning for slice 1
# Subset 0
# epoch:   1 | train accuracy: 0.99215 | test accuracy: 0.87205
# epoch:   2 | train accuracy: 0.99342 | test accuracy: 0.87353
# epoch:   3 | train accuracy: 0.99432 | test accuracy: 0.87191
# epoch:   4 | train accuracy: 0.99378 | test accuracy: 0.87312
# epoch:   5 | train accuracy: 0.99413 | test accuracy: 0.87386
# epoch:   6 | train accuracy: 0.99430 | test accuracy: 0.87265
# epoch:   7 | train accuracy: 0.99442 | test accuracy: 0.87238
# epoch:   8 | train accuracy: 0.99528 | test accuracy: 0.86915
# epoch:   9 | train accuracy: 0.99446 | test accuracy: 0.86646
# epoch:  10 | train accuracy: 0.99452 | test accuracy: 0.87386
# epoch:  11 | train accuracy: 0.99453 | test accuracy: 0.87292
# epoch:  12 | train accuracy: 0.99510 | test accuracy: 0.87339
# epoch:  13 | train accuracy: 0.99499 | test accuracy: 0.87171
# epoch:  14 | train accuracy: 0.99516 | test accuracy: 0.87130
# epoch:  15 | train accuracy: 0.99491 | test accuracy: 0.86908
# epoch:  16 | train accuracy: 0.99538 | test accuracy: 0.87083
# epoch:  17 | train accuracy: 0.99523 | test accuracy: 0.87420
# epoch:  18 | train accuracy: 0.99558 | test accuracy: 0.87427
# epoch:  19 | train accuracy: 0.99560 | test accuracy: 0.87433
# epoch:  20 | train accuracy: 0.99506 | test accuracy: 0.87359
# Confusion matrix for model0
# confusion matrix for normal scenario for slices : 5
# [[7638   67    0    0    0]
#  [   4 5334    0    0    0]
#  [  11    0    0    0    0]
#  [ 359   29    0    0    0]
#  [ 518  889    0    0    0]]
# Federated learning for slice 2
# Subset 1
# epoch:   1 | train accuracy: 0.99440 | test accuracy: 0.87824
# epoch:   2 | train accuracy: 0.99556 | test accuracy: 0.82275
# epoch:   3 | train accuracy: 0.99575 | test accuracy: 0.80625
# epoch:   4 | train accuracy: 0.99588 | test accuracy: 0.80322
# epoch:   5 | train accuracy: 0.99588 | test accuracy: 0.79844
# epoch:   6 | train accuracy: 0.99588 | test accuracy: 0.79406
# epoch:   7 | train accuracy: 0.99594 | test accuracy: 0.79083
# epoch:   8 | train accuracy: 0.99607 | test accuracy: 0.78531
# epoch:   9 | train accuracy: 0.99614 | test accuracy: 0.78302
# epoch:  10 | train accuracy: 0.99620 | test accuracy: 0.77527
# epoch:  11 | train accuracy: 0.99594 | test accuracy: 0.76800
# epoch:  12 | train accuracy: 0.99614 | test accuracy: 0.76995
# epoch:  13 | train accuracy: 0.99627 | test accuracy: 0.75978
# epoch:  14 | train accuracy: 0.99601 | test accuracy: 0.74571
# epoch:  15 | train accuracy: 0.99607 | test accuracy: 0.74295
# epoch:  16 | train accuracy: 0.99627 | test accuracy: 0.72456
# epoch:  17 | train accuracy: 0.99652 | test accuracy: 0.70463
# epoch:  18 | train accuracy: 0.99627 | test accuracy: 0.67015
# epoch:  19 | train accuracy: 0.99639 | test accuracy: 0.66941
# epoch:  20 | train accuracy: 0.99620 | test accuracy: 0.66718
# Confusion matrix for model1
# confusion matrix for normal scenario for slices : 5
# [[7696    0    9    0    0]
#  [ 839 2065 2434    0    0]
#  [   5    0    6    0    0]
#  [ 386    0    2    0    0]
#  [ 967    5  295    0  140]]
# Federated learning for slice 3
# Subset 2
# epoch:   1 | train accuracy: 0.91203 | test accuracy: 0.78227
# epoch:   2 | train accuracy: 0.92333 | test accuracy: 0.74133
# epoch:   3 | train accuracy: 0.92494 | test accuracy: 0.65324
# epoch:   4 | train accuracy: 0.92623 | test accuracy: 0.55788
# epoch:   5 | train accuracy: 0.93033 | test accuracy: 0.56873
# epoch:   6 | train accuracy: 0.92737 | test accuracy: 0.56293
# epoch:   7 | train accuracy: 0.93022 | test accuracy: 0.53418
# epoch:   8 | train accuracy: 0.93074 | test accuracy: 0.53606
# epoch:   9 | train accuracy: 0.93064 | test accuracy: 0.50704
# epoch:  10 | train accuracy: 0.93162 | test accuracy: 0.51956
# epoch:  11 | train accuracy: 0.93126 | test accuracy: 0.53579
# epoch:  12 | train accuracy: 0.93178 | test accuracy: 0.53310
# epoch:  13 | train accuracy: 0.92882 | test accuracy: 0.52084
# epoch:  14 | train accuracy: 0.93240 | test accuracy: 0.53115
# epoch:  15 | train accuracy: 0.93437 | test accuracy: 0.52017
# epoch:  16 | train accuracy: 0.93499 | test accuracy: 0.52940
# epoch:  17 | train accuracy: 0.93333 | test accuracy: 0.52839
# epoch:  18 | train accuracy: 0.93561 | test accuracy: 0.48737
# epoch:  19 | train accuracy: 0.93313 | test accuracy: 0.53317
# epoch:  20 | train accuracy: 0.93323 | test accuracy: 0.49209
# Confusion matrix for model2
# confusion matrix for normal scenario for slices : 5
# [[6927    0    0  778    0]
#  [ 948    0    0 4390    0]
#  [   2    0    0    9    0]
#  [   8    0    0  380    0]
#  [ 482    0    0  925    0]]
# Federated learning for slice 4
# Subset 3
# epoch:   1 | train accuracy: 0.98237 | test accuracy: 0.60334
# epoch:   2 | train accuracy: 0.98732 | test accuracy: 0.60738
# epoch:   3 | train accuracy: 0.98722 | test accuracy: 0.60603
# epoch:   4 | train accuracy: 0.98813 | test accuracy: 0.60617
# epoch:   5 | train accuracy: 0.98864 | test accuracy: 0.60590
# epoch:   6 | train accuracy: 0.98861 | test accuracy: 0.59789
# epoch:   7 | train accuracy: 0.98871 | test accuracy: 0.60839
# epoch:   8 | train accuracy: 0.98850 | test accuracy: 0.60772
# epoch:   9 | train accuracy: 0.98874 | test accuracy: 0.60866
# epoch:  10 | train accuracy: 0.98803 | test accuracy: 0.60758
# epoch:  11 | train accuracy: 0.98894 | test accuracy: 0.60819
# epoch:  12 | train accuracy: 0.98891 | test accuracy: 0.60644
# epoch:  13 | train accuracy: 0.98878 | test accuracy: 0.60758
# epoch:  14 | train accuracy: 0.98972 | test accuracy: 0.60637
# epoch:  15 | train accuracy: 0.98935 | test accuracy: 0.60745
# epoch:  16 | train accuracy: 0.98956 | test accuracy: 0.60684
# epoch:  17 | train accuracy: 0.98979 | test accuracy: 0.60536
# epoch:  18 | train accuracy: 0.99010 | test accuracy: 0.60718
# epoch:  19 | train accuracy: 0.98972 | test accuracy: 0.60529
# epoch:  20 | train accuracy: 0.98993 | test accuracy: 0.60765
# Confusion matrix for model3
# confusion matrix for normal scenario for slices : 5
# [[7627    0    0    0   78]
#  [ 302    0    0    0 5036]
#  [   9    0    0    0    2]
#  [ 211    0    0    0  177]
#  [  11    0    0    0 1396]]
# Federated learning for slice 5
# Subset 4
# epoch:   1 | train accuracy: 0.99974 | test accuracy: 0.52778
# epoch:   2 | train accuracy: 1.00000 | test accuracy: 0.52293
# epoch:   3 | train accuracy: 1.00000 | test accuracy: 0.52239
# epoch:   4 | train accuracy: 1.00000 | test accuracy: 0.52199
# epoch:   5 | train accuracy: 1.00000 | test accuracy: 0.52145
# epoch:   6 | train accuracy: 1.00000 | test accuracy: 0.52125
# epoch:   7 | train accuracy: 1.00000 | test accuracy: 0.52105
# epoch:   8 | train accuracy: 1.00000 | test accuracy: 0.52078
# epoch:   9 | train accuracy: 1.00000 | test accuracy: 0.52051
# epoch:  10 | train accuracy: 1.00000 | test accuracy: 0.52017
# epoch:  11 | train accuracy: 1.00000 | test accuracy: 0.52004
# epoch:  12 | train accuracy: 1.00000 | test accuracy: 0.51990
# epoch:  13 | train accuracy: 1.00000 | test accuracy: 0.51983
# epoch:  14 | train accuracy: 1.00000 | test accuracy: 0.51977
# epoch:  15 | train accuracy: 1.00000 | test accuracy: 0.51977
# epoch:  16 | train accuracy: 1.00000 | test accuracy: 0.51977
# epoch:  17 | train accuracy: 1.00000 | test accuracy: 0.51977
# epoch:  18 | train accuracy: 1.00000 | test accuracy: 0.51956
# epoch:  19 | train accuracy: 1.00000 | test accuracy: 0.51956
# epoch:  20 | train accuracy: 1.00000 | test accuracy: 0.51943
# Confusion matrix for model4
# confusion matrix for normal scenario for slices : 5
# [[7705    0    0    0    0]
#  [5330    8    0    0    0]
#  [  11    0    0    0    0]
#  [ 388    0    0    0    0]
#  [1400    7    0    0    0]]
# Iteration 7 : main_model accuracy on all test data:  0.8746
# Updating model :model0
# Updating model :model1
# Updating model :model2
# Updating model :model3
# Updating model :model4
# Federated learning for slice 1
# Subset 0
# epoch:   1 | train accuracy: 0.99286 | test accuracy: 0.87285
# epoch:   2 | train accuracy: 0.99427 | test accuracy: 0.87386
# epoch:   3 | train accuracy: 0.99419 | test accuracy: 0.87319
# epoch:   4 | train accuracy: 0.99436 | test accuracy: 0.87029
# epoch:   5 | train accuracy: 0.99487 | test accuracy: 0.87252
# epoch:   6 | train accuracy: 0.99483 | test accuracy: 0.87272
# epoch:   7 | train accuracy: 0.99525 | test accuracy: 0.87393
# epoch:   8 | train accuracy: 0.99485 | test accuracy: 0.86592
# epoch:   9 | train accuracy: 0.99506 | test accuracy: 0.87326
# epoch:  10 | train accuracy: 0.99509 | test accuracy: 0.86295
# epoch:  11 | train accuracy: 0.99551 | test accuracy: 0.87023
# epoch:  12 | train accuracy: 0.99513 | test accuracy: 0.87002
# epoch:  13 | train accuracy: 0.99560 | test accuracy: 0.87117
# epoch:  14 | train accuracy: 0.99501 | test accuracy: 0.87400
# epoch:  15 | train accuracy: 0.99560 | test accuracy: 0.87306
# epoch:  16 | train accuracy: 0.99589 | test accuracy: 0.87393
# epoch:  17 | train accuracy: 0.99557 | test accuracy: 0.87420
# epoch:  18 | train accuracy: 0.99549 | test accuracy: 0.87184
# epoch:  19 | train accuracy: 0.99561 | test accuracy: 0.87380
# epoch:  20 | train accuracy: 0.99593 | test accuracy: 0.86154
# Confusion matrix for model0
# confusion matrix for normal scenario for slices : 5
# [[7458  247    0    0    0]
#  [   3 5335    0    0    0]
#  [  11    0    0    0    0]
#  [ 340   48    0    0    0]
#  [ 668  739    0    0    0]]
# Federated learning for slice 2
# Subset 1
# epoch:   1 | train accuracy: 0.99478 | test accuracy: 0.88498
# epoch:   2 | train accuracy: 0.99536 | test accuracy: 0.85312
# epoch:   3 | train accuracy: 0.99575 | test accuracy: 0.81945
# epoch:   4 | train accuracy: 0.99614 | test accuracy: 0.80948
# ...
# epoch:  16 | train accuracy: 1.00000 | test accuracy: 0.74988
# epoch:  17 | train accuracy: 1.00000 | test accuracy: 0.74880
# epoch:  18 | train accuracy: 1.00000 | test accuracy: 0.74786
# epoch:  19 | train accuracy: 1.00000 | test accuracy: 0.74692
# epoch:  20 | train accuracy: 1.00000 | test accuracy: 0.74625
# Confusion matrix for model4
# confusion matrix for normal scenario for slices : 5
# [[7705    0    0    0    0]
#  [2219 3119    0    0    0]
#  [  11    0    0    0    0]
#  [ 388    0    0    0    0]
#  [1150    0    0    0  257]]
# Iteration 99 : main_model accuracy on all test data:  0.9379
# Updating model :model0
# Updating model :model1
# Updating model :model2
# Updating model :model3
# Updating model :model4
# Federated learning for slice 1
# Subset 0
# epoch:   1 | train accuracy: 0.99749 | test accuracy: 0.91427
# epoch:   2 | train accuracy: 0.99808 | test accuracy: 0.90464
# epoch:   3 | train accuracy: 0.99814 | test accuracy: 0.90255
# epoch:   4 | train accuracy: 0.99805 | test accuracy: 0.90908
# epoch:   5 | train accuracy: 0.99807 | test accuracy: 0.90121
# epoch:   6 | train accuracy: 0.99808 | test accuracy: 0.89568
# epoch:   7 | train accuracy: 0.99807 | test accuracy: 0.89669
# epoch:   8 | train accuracy: 0.99814 | test accuracy: 0.89541
# epoch:   9 | train accuracy: 0.99814 | test accuracy: 0.90181
# epoch:  10 | train accuracy: 0.99812 | test accuracy: 0.89656
# epoch:  11 | train accuracy: 0.99826 | test accuracy: 0.89602
# epoch:  12 | train accuracy: 0.99814 | test accuracy: 0.89488
# epoch:  13 | train accuracy: 0.99827 | test accuracy: 0.89474
# epoch:  14 | train accuracy: 0.99805 | test accuracy: 0.89528
# epoch:  15 | train accuracy: 0.99837 | test accuracy: 0.89521
# epoch:  16 | train accuracy: 0.99817 | test accuracy: 0.89218
# epoch:  17 | train accuracy: 0.99826 | test accuracy: 0.90040
# epoch:  18 | train accuracy: 0.99818 | test accuracy: 0.89562
# epoch:  19 | train accuracy: 0.99823 | test accuracy: 0.89326
# epoch:  20 | train accuracy: 0.99823 | test accuracy: 0.89407
# Confusion matrix for model0
# confusion matrix for normal scenario for slices : 5
# [[7664   41    0    0    0]
#  [   4 5334    0    0    0]
#  [  10    0    1    0    0]
#  [ 345   40    1    2    0]
#  [ 245  887    0    0  275]]
# Federated learning for slice 2
# Subset 1
# epoch:   1 | train accuracy: 0.99646 | test accuracy: 0.92323
# epoch:   2 | train accuracy: 0.99717 | test accuracy: 0.91400
# epoch:   3 | train accuracy: 0.99736 | test accuracy: 0.90713
# epoch:   4 | train accuracy: 0.99755 | test accuracy: 0.90794
# epoch:   5 | train accuracy: 0.99755 | test accuracy: 0.90174
# epoch:   6 | train accuracy: 0.99730 | test accuracy: 0.90013
# epoch:   7 | train accuracy: 0.99775 | test accuracy: 0.89952
# epoch:   8 | train accuracy: 0.99768 | test accuracy: 0.89454
# epoch:   9 | train accuracy: 0.99749 | test accuracy: 0.89636
# epoch:  10 | train accuracy: 0.99755 | test accuracy: 0.90073
# epoch:  11 | train accuracy: 0.99691 | test accuracy: 0.89824
# epoch:  12 | train accuracy: 0.99781 | test accuracy: 0.89952
# epoch:  13 | train accuracy: 0.99775 | test accuracy: 0.89716
# epoch:  14 | train accuracy: 0.99768 | test accuracy: 0.89589
# epoch:  15 | train accuracy: 0.99755 | test accuracy: 0.89488
# epoch:  16 | train accuracy: 0.99788 | test accuracy: 0.89494
# epoch:  17 | train accuracy: 0.99755 | test accuracy: 0.90114
# epoch:  18 | train accuracy: 0.99768 | test accuracy: 0.89393
# epoch:  19 | train accuracy: 0.99775 | test accuracy: 0.88922
# epoch:  20 | train accuracy: 0.99742 | test accuracy: 0.89164
# Confusion matrix for model1
# confusion matrix for normal scenario for slices : 5
# [[7698    0    7    0    0]
#  [ 431 4776  131    0    0]
#  [   5    0    6    0    0]
#  [ 362    1   24    1    0]
#  [ 623    1   24    0  759]]
# Federated learning for slice 3
# Subset 2
# epoch:   1 | train accuracy: 0.96169 | test accuracy: 0.92013
# epoch:   2 | train accuracy: 0.96796 | test accuracy: 0.92498
# epoch:   3 | train accuracy: 0.96682 | test accuracy: 0.89770
# epoch:   4 | train accuracy: 0.96910 | test accuracy: 0.92309
# epoch:   5 | train accuracy: 0.96703 | test accuracy: 0.91616
# epoch:   6 | train accuracy: 0.96801 | test accuracy: 0.90323
# epoch:   7 | train accuracy: 0.96864 | test accuracy: 0.90235
# epoch:   8 | train accuracy: 0.96822 | test accuracy: 0.91077
# epoch:   9 | train accuracy: 0.96630 | test accuracy: 0.90706
# epoch:  10 | train accuracy: 0.96636 | test accuracy: 0.89427
# epoch:  11 | train accuracy: 0.96858 | test accuracy: 0.89467
# epoch:  12 | train accuracy: 0.96807 | test accuracy: 0.90868
# epoch:  13 | train accuracy: 0.96708 | test accuracy: 0.91144
# epoch:  14 | train accuracy: 0.96724 | test accuracy: 0.89609
# epoch:  15 | train accuracy: 0.96801 | test accuracy: 0.89514
# epoch:  16 | train accuracy: 0.96874 | test accuracy: 0.89467
# epoch:  17 | train accuracy: 0.96656 | test accuracy: 0.89299
# epoch:  18 | train accuracy: 0.96610 | test accuracy: 0.89077
# epoch:  19 | train accuracy: 0.96703 | test accuracy: 0.89373
# epoch:  20 | train accuracy: 0.96713 | test accuracy: 0.88477
# Confusion matrix for model2
# confusion matrix for normal scenario for slices : 5
# [[7406    0    0  299    0]
#  [ 508 4418    0  407    5]
#  [   2    0    0    9    0]
#  [   7    0    0  381    0]
#  [ 197    9    0  268  933]]
# Federated learning for slice 4
# Subset 3
# epoch:   1 | train accuracy: 0.99362 | test accuracy: 0.62462
# epoch:   2 | train accuracy: 0.99481 | test accuracy: 0.62179
# epoch:   3 | train accuracy: 0.99508 | test accuracy: 0.61971
# epoch:   4 | train accuracy: 0.99563 | test accuracy: 0.61997
# epoch:   5 | train accuracy: 0.99505 | test accuracy: 0.62045
# epoch:   6 | train accuracy: 0.99529 | test accuracy: 0.61856
# epoch:   7 | train accuracy: 0.99569 | test accuracy: 0.61883
# epoch:   8 | train accuracy: 0.99532 | test accuracy: 0.61869
# epoch:   9 | train accuracy: 0.99501 | test accuracy: 0.61647
# epoch:  10 | train accuracy: 0.99542 | test accuracy: 0.61957
# epoch:  11 | train accuracy: 0.99596 | test accuracy: 0.61836
# epoch:  12 | train accuracy: 0.99535 | test accuracy: 0.61917
# epoch:  13 | train accuracy: 0.99539 | test accuracy: 0.61728
# epoch:  14 | train accuracy: 0.99535 | test accuracy: 0.61607
# epoch:  15 | train accuracy: 0.99508 | test accuracy: 0.61849
# epoch:  16 | train accuracy: 0.99573 | test accuracy: 0.61795
# epoch:  17 | train accuracy: 0.99512 | test accuracy: 0.61587
# epoch:  18 | train accuracy: 0.99529 | test accuracy: 0.61816
# epoch:  19 | train accuracy: 0.99522 | test accuracy: 0.61681
# epoch:  20 | train accuracy: 0.99583 | test accuracy: 0.61459
# Confusion matrix for model3
# confusion matrix for normal scenario for slices : 5
# [[7639    0    0    0   66]
#  [ 243   83    0    0 5012]
#  [   8    0    0    0    3]
#  [ 292    1    0    0   95]
#  [   3    0    0    0 1404]]
# Federated learning for slice 5
# Subset 4
# epoch:   1 | train accuracy: 0.99968 | test accuracy: 0.81271
# epoch:   2 | train accuracy: 1.00000 | test accuracy: 0.80995
# epoch:   3 | train accuracy: 1.00000 | test accuracy: 0.80861
# epoch:   4 | train accuracy: 1.00000 | test accuracy: 0.80746
# epoch:   5 | train accuracy: 1.00000 | test accuracy: 0.80665
# epoch:   6 | train accuracy: 1.00000 | test accuracy: 0.80598
# epoch:   7 | train accuracy: 1.00000 | test accuracy: 0.80558
# epoch:   8 | train accuracy: 1.00000 | test accuracy: 0.80504
# epoch:   9 | train accuracy: 1.00000 | test accuracy: 0.80436
# epoch:  10 | train accuracy: 1.00000 | test accuracy: 0.80369
# epoch:  11 | train accuracy: 1.00000 | test accuracy: 0.80322
# epoch:  12 | train accuracy: 1.00000 | test accuracy: 0.80268
# epoch:  13 | train accuracy: 1.00000 | test accuracy: 0.80248
# epoch:  14 | train accuracy: 1.00000 | test accuracy: 0.80194
# epoch:  15 | train accuracy: 1.00000 | test accuracy: 0.80147
# epoch:  16 | train accuracy: 1.00000 | test accuracy: 0.80106
# epoch:  17 | train accuracy: 1.00000 | test accuracy: 0.80046
# epoch:  18 | train accuracy: 1.00000 | test accuracy: 0.80032
# epoch:  19 | train accuracy: 1.00000 | test accuracy: 0.80019
# epoch:  20 | train accuracy: 1.00000 | test accuracy: 0.79992
# Confusion matrix for model4
# confusion matrix for normal scenario for slices : 5
# [[7705    0    0    0    0]
#  [1619 3719    0    0    0]
#  [  11    0    0    0    0]
#  [ 388    0    0    0    0]
#  [ 953    0    0    0  454]]
# Iteration 100 : main_model accuracy on all test data:  0.9409
# Updating model :model0
# Updating model :model1
# Updating model :model2
# Updating model :model3
# Updating model :model4
# Federated learning for slice 1
# Subset 0
# epoch:   1 | train accuracy: 0.99750 | test accuracy: 0.91292
# epoch:   2 | train accuracy: 0.99815 | test accuracy: 0.91131
# epoch:   3 | train accuracy: 0.99797 | test accuracy: 0.91225
# epoch:   4 | train accuracy: 0.99811 | test accuracy: 0.89865
# epoch:   5 | train accuracy: 0.99826 | test accuracy: 0.89898
# epoch:   6 | train accuracy: 0.99817 | test accuracy: 0.89508
# epoch:   7 | train accuracy: 0.99812 | test accuracy: 0.89656
# epoch:   8 | train accuracy: 0.99814 | test accuracy: 0.89447
# epoch:   9 | train accuracy: 0.99805 | test accuracy: 0.89952
# epoch:  10 | train accuracy: 0.99808 | test accuracy: 0.89737
# epoch:  11 | train accuracy: 0.99814 | test accuracy: 0.89723
# epoch:  12 | train accuracy: 0.99818 | test accuracy: 0.89817
# epoch:  13 | train accuracy: 0.99826 | test accuracy: 0.89454
# epoch:  14 | train accuracy: 0.99831 | test accuracy: 0.89885
# epoch:  15 | train accuracy: 0.99817 | test accuracy: 0.89528
# epoch:  16 | train accuracy: 0.99814 | test accuracy: 0.89144
# epoch:  17 | train accuracy: 0.99827 | test accuracy: 0.89205
# epoch:  18 | train accuracy: 0.99815 | test accuracy: 0.89683
# epoch:  19 | train accuracy: 0.99801 | test accuracy: 0.89454
# epoch:  20 | train accuracy: 0.99808 | test accuracy: 0.89259
# Confusion matrix for model0
# confusion matrix for normal scenario for slices : 5
# [[7662   43    0    0    0]
#  [   3 5335    0    0    0]
#  [  10    0    1    0    0]
#  [ 334   51    1    2    0]
#  [ 185  968    0    0  254]]
# Federated learning for slice 2
# Subset 1
# epoch:   1 | train accuracy: 0.99697 | test accuracy: 0.92154
# epoch:   2 | train accuracy: 0.99710 | test accuracy: 0.91710
# epoch:   3 | train accuracy: 0.99723 | test accuracy: 0.91232
# epoch:   4 | train accuracy: 0.99717 | test accuracy: 0.90855
# epoch:   5 | train accuracy: 0.99755 | test accuracy: 0.90706
# epoch:   6 | train accuracy: 0.99768 | test accuracy: 0.90855
# epoch:   7 | train accuracy: 0.99742 | test accuracy: 0.90518
# epoch:   8 | train accuracy: 0.99755 | test accuracy: 0.90430
# epoch:   9 | train accuracy: 0.99775 | test accuracy: 0.90013
# epoch:  10 | train accuracy: 0.99762 | test accuracy: 0.89865
# epoch:  11 | train accuracy: 0.99762 | test accuracy: 0.90356
# epoch:  12 | train accuracy: 0.99768 | test accuracy: 0.89824
# epoch:  13 | train accuracy: 0.99807 | test accuracy: 0.90269
# epoch:  14 | train accuracy: 0.99749 | test accuracy: 0.90235
# epoch:  15 | train accuracy: 0.99768 | test accuracy: 0.89844
# epoch:  16 | train accuracy: 0.99781 | test accuracy: 0.89804
# epoch:  17 | train accuracy: 0.99749 | test accuracy: 0.89993
# epoch:  18 | train accuracy: 0.99742 | test accuracy: 0.89548
# epoch:  19 | train accuracy: 0.99762 | test accuracy: 0.89299
# epoch:  20 | train accuracy: 0.99730 | test accuracy: 0.89312
# Confusion matrix for model1
# confusion matrix for normal scenario for slices : 5
# [[7699    0    6    0    0]
#  [ 410 4807  120    0    1]
#  [   5    0    6    0    0]
#  [ 364    1   22    1    0]
#  [ 631    3   24    0  749]]
# Federated learning for slice 3
# Subset 2
# epoch:   1 | train accuracy: 0.96029 | test accuracy: 0.91690
# epoch:   2 | train accuracy: 0.96750 | test accuracy: 0.91683
# epoch:   3 | train accuracy: 0.96630 | test accuracy: 0.91622
# epoch:   4 | train accuracy: 0.96677 | test accuracy: 0.91643
# epoch:   5 | train accuracy: 0.96703 | test accuracy: 0.92175
# epoch:   6 | train accuracy: 0.96900 | test accuracy: 0.89710
# epoch:   7 | train accuracy: 0.96537 | test accuracy: 0.90814
# epoch:   8 | train accuracy: 0.96698 | test accuracy: 0.90006
# epoch:   9 | train accuracy: 0.96656 | test accuracy: 0.90161
# epoch:  10 | train accuracy: 0.96636 | test accuracy: 0.90552
# epoch:  11 | train accuracy: 0.96884 | test accuracy: 0.90491
# epoch:  12 | train accuracy: 0.96864 | test accuracy: 0.90013
# epoch:  13 | train accuracy: 0.96682 | test accuracy: 0.90141
# epoch:  14 | train accuracy: 0.96900 | test accuracy: 0.90168
# epoch:  15 | train accuracy: 0.96926 | test accuracy: 0.88168
# epoch:  16 | train accuracy: 0.96630 | test accuracy: 0.89063
# epoch:  17 | train accuracy: 0.96884 | test accuracy: 0.89198
# epoch:  18 | train accuracy: 0.96827 | test accuracy: 0.89393
# epoch:  19 | train accuracy: 0.96719 | test accuracy: 0.89050
# epoch:  20 | train accuracy: 0.96786 | test accuracy: 0.88841
# Confusion matrix for model2
# confusion matrix for normal scenario for slices : 5
# [[7588    0    0  117    0]
#  [ 501 4279    5  540   13]
#  [   2    0    0    9    0]
#  [   6    0    0  382    0]
#  [ 178    8    0  278  943]]
# Federated learning for slice 4
# Subset 3
# epoch:   1 | train accuracy: 0.99335 | test accuracy: 0.62098
# epoch:   2 | train accuracy: 0.99478 | test accuracy: 0.62112
# epoch:   3 | train accuracy: 0.99461 | test accuracy: 0.62072
# epoch:   4 | train accuracy: 0.99498 | test accuracy: 0.62105
# epoch:   5 | train accuracy: 0.99495 | test accuracy: 0.61937
# epoch:   6 | train accuracy: 0.99485 | test accuracy: 0.62078
# epoch:   7 | train accuracy: 0.99488 | test accuracy: 0.61829
# epoch:   8 | train accuracy: 0.99559 | test accuracy: 0.61762
# epoch:   9 | train accuracy: 0.99542 | test accuracy: 0.61964
# epoch:  10 | train accuracy: 0.99529 | test accuracy: 0.61661
# epoch:  11 | train accuracy: 0.99529 | test accuracy: 0.61587
# epoch:  12 | train accuracy: 0.99532 | test accuracy: 0.61829
# epoch:  13 | train accuracy: 0.99532 | test accuracy: 0.61856
# epoch:  14 | train accuracy: 0.99549 | test accuracy: 0.61869
# epoch:  15 | train accuracy: 0.99542 | test accuracy: 0.62011
# epoch:  16 | train accuracy: 0.99549 | test accuracy: 0.61856
# epoch:  17 | train accuracy: 0.99539 | test accuracy: 0.61890
# epoch:  18 | train accuracy: 0.99525 | test accuracy: 0.61856
# epoch:  19 | train accuracy: 0.99546 | test accuracy: 0.61829
# epoch:  20 | train accuracy: 0.99549 | test accuracy: 0.61688
# Confusion matrix for model3
# confusion matrix for normal scenario for slices : 5
# [[7649    0    0    0   56]
#  [ 258  109    0    0 4971]
#  [   7    0    0    0    4]
#  [ 277    1    0    0  110]
#  [   5    0    0    0 1402]]
# Federated learning for slice 5
# Subset 4
# epoch:   1 | train accuracy: 0.99948 | test accuracy: 0.79440
# epoch:   2 | train accuracy: 1.00000 | test accuracy: 0.79258
# epoch:   3 | train accuracy: 1.00000 | test accuracy: 0.79015
# epoch:   4 | train accuracy: 1.00000 | test accuracy: 0.78861
# epoch:   5 | train accuracy: 1.00000 | test accuracy: 0.78672
# epoch:   6 | train accuracy: 1.00000 | test accuracy: 0.78510
# epoch:   7 | train accuracy: 1.00000 | test accuracy: 0.78355
# epoch:   8 | train accuracy: 1.00000 | test accuracy: 0.78214
# epoch:   9 | train accuracy: 1.00000 | test accuracy: 0.78120
# epoch:  10 | train accuracy: 1.00000 | test accuracy: 0.78025
# epoch:  11 | train accuracy: 1.00000 | test accuracy: 0.77918
# epoch:  12 | train accuracy: 1.00000 | test accuracy: 0.77830
# epoch:  13 | train accuracy: 1.00000 | test accuracy: 0.77743
# epoch:  14 | train accuracy: 1.00000 | test accuracy: 0.77662
# epoch:  15 | train accuracy: 1.00000 | test accuracy: 0.77601
# epoch:  16 | train accuracy: 1.00000 | test accuracy: 0.77534
# epoch:  17 | train accuracy: 1.00000 | test accuracy: 0.77426
# epoch:  18 | train accuracy: 1.00000 | test accuracy: 0.77359
# epoch:  19 | train accuracy: 1.00000 | test accuracy: 0.77271
# epoch:  20 | train accuracy: 1.00000 | test accuracy: 0.77231
# Confusion matrix for model4
# confusion matrix for normal scenario for slices : 5
# [[7705    0    0    0    0]
#  [1901 3437    0    0    0]
#  [  11    0    0    0    0]
#  [ 388    0    0    0    0]
#  [1074    7    0    0  326]]
# Iteration 101 : main_model accuracy on all test data:  0.9391

# %%
file = open(file_name, "a")
confusion_mat(main_model, test_dl, desc = 'Confusion matrix for after 10 rounds of the dataset')
# Out:
# Confusion matrix for after 10 rounds of the dataset
# confusion matrix for normal scenario for slices : 5
# [[7705    0    0    0    0]
#  [ 280 5056    0    0    2]
#  [   6    0    5    0    0]
#  [ 337    3    1   47    0]
#  [ 256   12    0    7 1132]]

# %% [markdown]
# The accuracy of the centralized model was calculated as approximately 98%. The accuracy of the main model obtained by FedAvg method started from 85% and improved to 94%. In this case, we can say that although the main model obtained by FedAvg method was trained without seeing the data, its performance cannot be underestimated.

# %%
file.close()
